# %%
import sys
from collections import Counter, defaultdict

# %%
# !dos2unix /tmp/o2.txt
# Out:
# dos2unix: converting file /tmp/o2.txt to Unix format...

# %%
#!apt-get install --yes dos2unix

# %%
# !cat /tmp/o2.txt | sed 's/\//, /g' | sed 's/\;/,/g' | sed 's/\‚/,/g' | sed '/^$/d' | sed 's/\ \,/\,/g' | sed 's/\ \ /\ /g' | sed '/\,$/d' | sed '/\,\ $/d' > /tmp/f3.txt

# %%
input_file = '/tmp/f3.txt'
lines = open(input_file).read().splitlines()

# %%
outerlist = list()
for i in lines:
    mylist = list()
    for x in i.split(","):
        mylist.append(x.strip())
    outerlist.append(mylist)

# %%
theList = [x for x in outerlist if x != [""]]
for i in range(len(theList)):
    theList[i] = list(filter(None, theList[i]))

# %%
mylist = list()
for i in theList:
    for x in i:
        mylist.append(x)

# %%
c = Counter(mylist)
[el for el in c.items() if el[1] > 1]
# Out:
# [('अकटोविकट', 2),
#  ('अगडबंब', 2),
#  ('प्रचंड', 4),
#  ('अचाट', 5),
#  ('अफाट', 6),
#  ('विशाल', 3),
#  ('भव्य', 2),
#  ('अवजड', 2),
#  ('बोजड', 2),
#  ('अकरणीय', 3),
#  ('अविहित', 3),
#  ('निषिद्ध', 3),
#  ('त्याज्य', 3),
#  ('अयोग्य', 4),
#  ('बेकायदेशीर', 4),
#  ('द्वाड', 3),
#  ('कठोर', 2),
#  ('निष्ठुर', 2),
#  ('निर्दय', 4),
#  ('क्रूर', 4),
#  ('अकल्पित', 3),
#  ('अनपेक्षित', 3),
#  ('आकस्मिक', 3),
#  ('आगंतुक', 3),
#  ('अनाहूत', 2),
#  ('अकस्मात', 3),
#  ('अकल्याण', 2),
#  ('हानी', 4),
#  ('नुकसान', 3),
#  ('अपाय', 2),
#  ('अपकार', 2),
#  ('अशुभ', 5),
#  ('अमंगल', 3),
#  ('अनिष्ट', 4),
#  ('अपघात', 2),
#  ('योगायोग', 3),
#  ('अकारण', 2),
#  ('विनाकारण', 2),
#  ('निरुद्देश', 2),
#  ('अहेतुक', 2),
#  ('व्यर्थ', 3),
#  ('निरर्थक', 2),
#  ('दुर्भिक्ष', 2),
#  ('वाण', 3),
#  ('चणचण', 2),
#  ('गरीब', 2),
#  ('नंगा', 2),
#  ('अभाव', 2),
#  ('अंकित', 2),
#  ('अंकुर', 2),
#  ('मोड', 2),
#  ('लागणे', 2),
#  ('अंकुश', 2),
#  ('ताबा', 2),
#  ('हुकमत', 3),
#  ('नियंत्रण', 4),
#  ('निर्बंध', 5),
#  ('मर्यादा', 3),
#  ('सहज', 4),
#  ('निसर्गदत्त', 2),
#  ('स्वयंभू', 2),
#  ('उपजत', 2),
#  ('स्वयंस्फूर्त', 2),
#  ('शुद्ध', 6),
#  ('अस्सल', 2),
#  ('खरा', 2),
#  ('निष्पाप', 2),
#  ('निष्कपट', 2),
#  ('अल्लड', 3),
#  ('निर्हेतुक', 2),
#  ('सरळ', 2),
#  ('अक्कडबाज', 2),
#  ('छकडा', 2),
#  ('अलबेला', 2),
#  ('बुद्धी', 2),
#  ('आकलनशक्ती', 2),
#  ('दु:स्थिती', 2),
#  ('अवदशा', 2),
#  ('आपत्ती', 2),
#  ('दुर्बुद्धी', 2),
#  ('अखंड', 5),
#  ('अखंडित', 2),
#  ('अभंग', 3),
#  ('अत्रुटित', 3),
#  ('अस्खलित', 2),
#  ('अभेद्य', 3),
#  ('अविभाज्य', 3),
#  ('सलग', 2),
#  ('सगळा', 2),
#  ('सबंध', 3),
#  ('अख्खा', 2),
#  ('एक', 2),
#  ('एकसंध', 3),
#  ('अक्षत', 3),
#  ('अतूट', 3),
#  ('अवघा', 2),
#  ('पूर्ण', 2),
#  ('संपूर्ण', 3),
#  ('समग्र', 2),
#  ('अविभक्त', 3),
#  ('अविरत', 3),
#  ('निरंतर', 3),
#  ('अव्याहत', 2),
#  ('अविनाशी', 2),
#  ('अनश्वर', 3),
#  ('शाश्वत', 4),
#  ('चिर', 2),
#  ('चिरंतन', 3),
#  ('चिरस्थायी', 3),
#  ('कायम', 3),
#  ('अक्षय', 3),
#  ('अनंत', 4),
#  ('सतत', 2),
#  ('नित्य', 3),
#  ('अनिरुद्ध', 2),
#  ('अप्रतिहत', 3),
#  ('बेचव', 2),
#  ('अखेर', 2),
#  ('शेवट', 3),
#  ('अंत', 3),
#  ('समाप्ती', 2),
#  ('परिसमाप्ती', 2),
#  ('सांगता', 2),
#  ('पूर्णविराम', 2),
#  ('अस्त', 2),
#  ('लय', 2),
#  ('विलय', 2),
#  ('विसर्जन', 2),
#  ('बरखास्ती', 2),
#  ('बोळवण', 2),
#  ('गती', 2),
#  ('गत', 2),
#  ('नाश', 4),
#  ('टोक', 2),
#  ('शेपूट', 2),
#  ('कड', 2),
#  ('सीमा', 3),
#  ('परिसीमा', 3),
#  ('हद्द', 3),
#  ('कळस', 4),
#  ('उपसंहार', 2),
#  ('आटोपणे', 2),
#  ('अवयव', 2),
#  ('विभाग', 3),
#  ('घटक', 2),
#  ('हिस्सा', 2),
#  ('शाखा', 2),
#  ('कल', 2),
#  ('प्रवृत्ती', 2),
#  ('क्षमता', 4),
#  ('कुळागर', 2),
#  ('फड', 3),
#  ('असहाय', 2),
#  ('निराधार', 3),
#  ('दिङ्मूढ', 3),
#  ('अगत्य', 5),
#  ('आस्था', 5),
#  ('आपुलकी', 3),
#  ('सद्भाव', 3),
#  ('कळकळ', 5),
#  ('पाहुणचार', 2),
#  ('स्वागत', 2),
#  ('आगतस्वागत', 2),
#  ('आग्रह', 2),
#  ('पानसुपारी', 2),
#  ('अत्तरगुलाब', 2),
#  ('मानसन्मान', 2),
#  ('शिष्टाचार', 2),
#  ('कदर', 4),
#  ('अवश्य', 2),
#  ('अगम्य', 2),
#  ('अतर्क्य', 3),
#  ('अज्ञेय', 2),
#  ('अगाध', 2),
#  ('कल्पनातीत', 3),
#  ('गूढ', 4),
#  ('गहन', 2),
#  ('दुर्बोध', 3),
#  ('दुर्गम', 2),
#  ('गुप्त', 2),
#  ('अलभ्य', 3),
#  ('अप्राप्य', 3),
#  ('बांधा', 2),
#  ('हाड', 2),
#  ('घाट', 3),
#  ('ठेवण', 2),
#  ('गोंधळ', 5),
#  ('गडबड', 4),
#  ('धुमाळी', 2),
#  ('थैमान', 2),
#  ('दंगा', 2),
#  ('खळबळ', 3),
#  ('धुमश्चक्री', 3),
#  ('बोभाटा', 2),
#  ('अमर्याद', 7),
#  ('स्वीकृती', 2),
#  ('संमती', 3),
#  ('अनुमती', 3),
#  ('मान्यता', 3),
#  ('रुकार', 3),
#  ('मंजुरी', 2),
#  ('कबुली', 2),
#  ('कवटाळणे', 2),
#  ('अगोचर', 2),
#  ('खट्याळ', 3),
#  ('खोडकर', 2),
#  ('व्रात्य', 2),
#  ('आगाऊ', 2),
#  ('बंड', 3),
#  ('चावट', 4),
#  ('अर्वाच्य', 5),
#  ('होम', 2),
#  ('चिता', 2),
#  ('भट्टी', 2),
#  ('दहन', 2),
#  ('दाह', 3),
#  ('रखरख', 2),
#  ('जळणे', 2),
#  ('धगधगणे', 2),
#  ('भाजणे', 2),
#  ('अणकुची', 2),
#  ('शिखर', 2),
#  ('प्रथमस्थान', 2),
#  ('आघाडी', 2),
#  ('बिनी', 2),
#  ('प्रथम', 3),
#  ('पहिला', 2),
#  ('अध्वर्यू', 2),
#  ('धुरीण', 2),
#  ('प्रमुख', 2),
#  ('श्रेष्ठ', 3),
#  ('सर्वश्रेष्ठ', 2),
#  ('परम', 2),
#  ('लोकोत्तर', 3),
#  ('थोर', 2),
#  ('निपुण', 2),
#  ('अध्यक्ष', 2),
#  ('आद्य', 2),
#  ('विलक्षण', 5),
#  ('चमत्कारिक', 3),
#  ('चमत्कृतिपूर्ण', 2),
#  ('विचित्र', 2),
#  ('अद्भुत', 5),
#  ('अभूतपूर्व', 2),
#  ('अजब', 3),
#  ('आश्चर्यकारक', 2),
#  ('असंभाव्य', 2),
#  ('विस्तृत', 2),
#  ('मोकळा', 2),
#  ('खुला', 3),
#  ('अघोरी', 2),
#  ('दुष्ट', 5),
#  ('राक्षसी', 2),
#  ('सैतानी', 3),
#  ('पाशवी', 3),
#  ('अमानुष', 3),
#  ('रानटी', 5),
#  ('जंगली', 3),
#  ('भेसूर', 2),
#  ('भीषण', 2),
#  ('दारुण', 3),
#  ('घोर', 2),
#  ('निंद्य', 4),
#  ('गर्हणीय', 2),
#  ('अतिरेकी', 4),
#  ('अमंगळ', 2),
#  ('अपवित्र', 2),
#  ('दु:सह', 2),
#  ('अचंबा', 2),
#  ('नवल', 2),
#  ('विस्मय', 2),
#  ('आश्चर्य', 3),
#  ('चमत्कार', 2),
#  ('अढळ', 2),
#  ('निश्चित', 2),
#  ('पक्का', 2),
#  ('स्तब्ध', 2),
#  ('निमूट', 2),
#  ('निश्चेष्ट', 2),
#  ('खंबीर', 2),
#  ('अलौकिक', 3),
#  ('अपूर्व', 3),
#  ('असामान्य', 3),
#  ('बेसुमार', 2),
#  ('पराकोटीचा', 2),
#  ('अतिशय', 2),
#  ('अचूक', 3),
#  ('बिनचूक', 2),
#  ('निर्दोष', 4),
#  ('असंदिग्ध', 2),
#  ('तंतोतंत', 2),
#  ('विश्वसनीय', 2),
#  ('अमोघ', 3),
#  ('जड', 3),
#  ('अपेक्षा', 5),
#  ('अंदाज', 2),
#  ('अटकळ', 2),
#  ('संशय', 3),
#  ('शंका', 5),
#  ('मत', 3),
#  ('कल्पना', 3),
#  ('आराखडा', 3),
#  ('अजागळ', 3),
#  ('अव्यवस्थित', 5),
#  ('अकुशल', 3),
#  ('भोंगळ', 3),
#  ('गबाळग्रंथी', 2),
#  ('ध्यान', 3),
#  ('अजाण', 2),
#  ('अज्ञान', 3),
#  ('अविद्य', 2),
#  ('अनभ्यस्त', 2),
#  ('अडाणी', 4),
#  ('अप्रगल्भ', 2),
#  ('अल्पबुद्धी', 2),
#  ('अननुभवी', 2),
#  ('अपक्व', 3),
#  ('अपरिपक्व', 2),
#  ('असमंजस', 2),
#  ('कोवळा', 3),
#  ('कच्चा', 2),
#  ('बाल', 2),
#  ('आचरट', 5),
#  ('कोरा', 4),
#  ('व्यवहारशून्य', 2),
#  ('अशिक्षित', 2),
#  ('खेडवळ', 2),
#  ('गावंढळ', 2),
#  ('गावरान', 2),
#  ('रानवट', 2),
#  ('असंस्कृत', 6),
#  ('अनागर', 2),
#  ('अप्रबुद्ध', 2),
#  ('बुद्धिमंद', 2),
#  ('मंद', 2),
#  ('मूर्ख', 3),
#  ('टोणपा', 2),
#  ('बैलोबा', 2),
#  ('अजिंक्य', 2),
#  ('अजेय', 2),
#  ('दुर्दम्य', 3),
#  ('अनावर', 3),
#  ('अगदी', 2),
#  ('अनन्यसाधारण', 2),
#  ('सर्वोत्तम', 2),
#  ('अट', 3),
#  ('बंध', 2),
#  ('नियम', 4),
#  ('अटक', 2),
#  ('मोहक', 3),
#  ('अटकाव', 2),
#  ('अडथळा', 3),
#  ('अडसर', 2),
#  ('अडचण', 4),
#  ('व्यत्यय', 3),
#  ('विघ्न', 3),
#  ('विक्षेप', 2),
#  ('खंड', 6),
#  ('संकट', 2),
#  ('कोंडी', 2),
#  ('अंतराय', 2),
#  ('हरकत', 3),
#  ('तक्रार', 2),
#  ('प्रतिबंध', 2),
#  ('विरोध', 3),
#  ('अटळ', 2),
#  ('अपरिहार्य', 2),
#  ('अनिवार्य', 3),
#  ('आवश्यक', 2),
#  ('अत्यावश्यक', 2),
#  ('प्राप्त', 2),
#  ('भाग', 4),
#  ('कार्यक्षम', 2),
#  ('अर्क', 2),
#  ('उत्कृष्ट', 2),
#  ('परिपूर्ण', 4),
#  ('गावणे', 2),
#  ('अडणे', 2),
#  ('निरुपयोगी', 2),
#  ('रद्द', 2),
#  ('गबाळ', 2),
#  ('पसारा', 2),
#  ('त्रास', 2),
#  ('उपाधी', 3),
#  ('गोता', 2),
#  ('कमतरता', 3),
#  ('टंचाई', 2),
#  ('व्यापार', 2),
#  ('हट्टी', 2),
#  ('तळ', 2),
#  ('जागा', 3),
#  ('स्थान', 3),
#  ('वसती', 2),
#  ('गट', 2),
#  ('अढी', 2),
#  ('ग्रह', 3),
#  ('कडवटपणा', 2),
#  ('पीळ', 2),
#  ('आकस', 2),
#  ('अदावत', 2),
#  ('असूया', 2),
#  ('घुस्सा', 2),
#  ('अवसान', 4),
#  ('प्रलय', 3),
#  ('संहार', 2),
#  ('पडदा', 2),
#  ('निरोप', 2),
#  ('पराभव', 2),
#  ('पाडाव', 2),
#  ('अंतर', 3),
#  ('न्यूनाधिक्य', 2),
#  ('पक्षपात', 2),
#  ('मध्यांतर', 2),
#  ('अवधी', 3),
#  ('टप्पा', 2),
#  ('पल्ला', 2),
#  ('धाव', 2),
#  ('मध्यभाग', 2),
#  ('अंतराळ', 2),
#  ('आभाळ', 2),
#  ('अवकाश', 3),
#  ('वातावरण', 2),
#  ('मधला', 2),
#  ('गुंतलेला', 2),
#  ('संबंधित', 3),
#  ('अनुस्यूत', 2),
#  ('शिरकाव', 2),
#  ('अतिक्रमण', 2),
#  ('लंघन', 2),
#  ('मर्यादातिक्रमण', 2),
#  ('अतिक्रम', 2),
#  ('आक्रमण', 2),
#  ('घुसखोरी', 2),
#  ('स्वारी', 2),
#  ('चाल', 2),
#  ('अमर्यादा', 3),
#  ('अतिरेक', 2),
#  ('झोड', 2),
#  ('तडाखा', 4),
#  ('तीव्रता', 2),
#  ('प्रकोप', 3),
#  ('असीम', 2),
#  ('अपार', 2),
#  ('अपरिमित', 3),
#  ('अमित', 3),
#  ('अमाप', 4),
#  ('अपरंपार', 2),
#  ('आत्यंतिक', 2),
#  ('भरमसाट', 2),
#  ('अवाजवी', 3),
#  ('वारेमाप', 2),
#  ('बेफाम', 5),
#  ('अनिवार', 2),
#  ('विपुल', 2),
#  ('पुष्कळ', 2),
#  ('फार', 2),
#  ('खूप', 2),
#  ('चिकार', 2),
#  ('मुबलक', 2),
#  ('महामूर', 2),
#  ('उदंड', 3),
#  ('तुफान', 3),
#  ('कमालीचा', 2),
#  ('पोकळ', 2),
#  ('अवडंबर', 3),
#  ('प्राचीन', 2),
#  ('अतृप्त', 4),
#  ('असमाधानी', 2),
#  ('असंतुष्ट', 3),
#  ('असंतोषी', 2),
#  ('हावरट', 2),
#  ('अधाशी', 2),
#  ('लोभी', 4),
#  ('उमेदवार', 3),
#  ('शागीर्द', 2),
#  ('अनुयायी', 2),
#  ('मदतनीस', 2),
#  ('जुलूम', 2),
#  ('जबरदस्ती', 3),
#  ('लाठीमार', 2),
#  ('छळ', 2),
#  ('अस्थी', 2),
#  ('श्रद्धांजली', 2),
#  ('तर्पण', 2),
#  ('सौहार्द', 2),
#  ('आदर', 2),
#  ('सुसंस्कृतता', 2),
#  ('डौल', 3),
#  ('आर्जव', 4),
#  ('उतावळा', 3),
#  ('अविचारी', 3),
#  ('अविवेकी', 3),
#  ('भविष्यमाण', 2),
#  ('ईश्वरेच्छा', 2),
#  ('शासन', 2),
#  ('ठोकर', 2),
#  ('नवलाईचा', 2),
#  ('अनोखा', 3),
#  ('असाधारण', 2),
#  ('सख्य', 3),
#  ('एकवाक्यता', 2),
#  ('अंध', 2),
#  ('हीन', 2),
#  ('पापी', 2),
#  ('दुराचारी', 2),
#  ('नीतिभ्रष्ट', 2),
#  ('बदफैली', 2),
#  ('अनीतिमान', 2),
#  ('अधांतरी', 2),
#  ('वर', 2),
#  ('हावरा', 2),
#  ('हपापलेला', 2),
#  ('आसक्त', 2),
#  ('अधिक', 2),
#  ('जास्त', 2),
#  ('जादा', 2),
#  ('आणखी', 2),
#  ('वरकड', 2),
#  ('अतिरिक्त', 2),
#  ('पूरक', 2),
#  ('अधिष्ठान', 4),
#  ('दावा', 2),
#  ('प्रभुत्व', 2),
#  ('हुकूम', 3),
#  ('प्रभाव', 2),
#  ('हुद्दा', 2),
#  ('प्रतिष्ठा', 2),
#  ('मान', 2),
#  ('अधिकारी', 2),
#  ('स्वामी', 2),
#  ('धनी', 2),
#  ('मालक', 2),
#  ('अधीक्षक', 3),
#  ('नियामक', 2),
#  ('बैठक', 2),
#  ('आसन', 2),
#  ('निवास', 2),
#  ('अधिवास', 2),
#  ('वास्तव्य', 2),
#  ('वसतिस्थान', 3),
#  ('अधीर', 3),
#  ('आतुर', 4),
#  ('उत्सुक', 3),
#  ('उत्कंठित', 4),
#  ('उतावीळ', 2),
#  ('अस्वस्थ', 2),
#  ('बेचैन', 2),
#  ('परागती', 2),
#  ('घट', 2),
#  ('ढाळ', 2),
#  ('पीछेहाट', 3),
#  ('कोसळणे', 2),
#  ('अध्ययन', 3),
#  ('अभ्यास', 2),
#  ('पठण', 3),
#  ('मनन', 2),
#  ('चिंतन', 3),
#  ('परिशीलन', 2),
#  ('संशोधन', 2),
#  ('अन्वेषण', 3),
#  ('आलोचन', 2),
#  ('सराव', 2),
#  ('परिपाठ', 2),
#  ('पुनरावृत्ती', 2),
#  ('आवर्तन', 2),
#  ('पाठांतर', 2),
#  ('वाचणे', 2),
#  ('सूत्रधार', 2),
#  ('अध्यात्म', 2),
#  ('आचार्य', 2),
#  ('प्रवेश', 2),
#  ('पाठ', 3),
#  ('अनघ', 2),
#  ('निष्कलंक', 2),
#  ('निर्लेप', 2),
#  ('पवित्र', 3),
#  ('स्वच्छ', 3),
#  ('अमेय', 3),
#  ('असंख्य', 2),
#  ('अगणित', 2),
#  ('अमर', 3),
#  ('नवा', 5),
#  ('नवखा', 2),
#  ('संकोच', 2),
#  ('भीड', 3),
#  ('द्विधावृत्ती', 2),
#  ('उपेक्षा', 2),
#  ('अनादर', 2),
#  ('अवज्ञा', 2),
#  ('हयगय', 5),
#  ('अनर्गल', 3),
#  ('स्वैर', 4),
#  ('अप्रतिबंध', 2),
#  ('बेबंद', 3),
#  ('बेछूट', 2),
#  ('उद्दाम', 2),
#  ('बेताल', 2),
#  ('अरिष्ट', 2),
#  ('विपत्ती', 2),
#  ('अनवधान', 2),
#  ('दुर्लक्ष', 2),
#  ('हेळसांड', 2),
#  ('गाफीलपणा', 2),
#  ('निष्काळजीपणा', 2),
#  ('कर्तव्यच्युती', 3),
#  ('ढिलाई', 2),
#  ('दुराचार', 2),
#  ('दुराचरण', 2),
#  ('दुर्वर्तन', 2),
#  ('नीतिभ्रष्टता', 2),
#  ('अनीती', 2),
#  ('अधर्म', 2),
#  ('गैरव्यवहार', 2),
#  ('अनाथ', 2),
#  ('गृहहीन', 2),
#  ('अनिकेत', 2),
#  ('मूळचा', 2),
#  ('हमी', 2),
#  ('हवाला', 2),
#  ('ठेव', 2),
#  ('अनामिक', 3),
#  ('अज्ञात', 3),
#  ('अनोळखी', 4),
#  ('अप्रसिद्ध', 4),
#  ('अप्रीती', 4),
#  ('नावड', 2),
#  ('नाखुशी', 4),
#  ('कंटाळा', 2),
#  ('नापसंती', 4),
#  ('तिरस्कार', 2),
#  ('तिटकारा', 2),
#  ('आटोक्याबाहेरचा', 2),
#  ('अनियंत्रित', 2),
#  ('बेलगाम', 3),
#  ('भटक्या', 2),
#  ('वाह्यात', 3),
#  ('बेशिस्त', 6),
#  ('मुक्त', 2),
#  ('लहरी', 3),
#  ('बेकायदा', 2),
#  ('अनियमित', 2),
#  ('चंचल', 3),
#  ('अस्थिर', 4),
#  ('अनिश्चित', 2),
#  ('डळमळीत', 2),
#  ('भ्रांत', 2),
#  ('संदिग्ध', 2),
#  ('मोघम', 2),
#  ('अस्पष्ट', 3),
#  ('पुसट', 2),
#  ('साशंकता', 2),
#  ('संभ्रम', 2),
#  ('पेचप्रसंग', 2),
#  ('चलबिचल', 3),
#  ('अनुकंपा', 2),
#  ('कृपा', 3),
#  ('माया', 4),
#  ('ममता', 3),
#  ('मायाळूपणा', 2),
#  ('नक्कल', 2),
#  ('प्रतिकृती', 2),
#  ('प्रत', 2),
#  ('आवृत्ती', 2),
#  ('नमुना', 3),
#  ('बतावणी', 3),
#  ('अभिनय', 3),
#  ('सोंग', 2),
#  ('विडंबन', 2),
#  ('अनुकूल', 2),
#  ('आश्वासक', 2),
#  ('प्रोत्साहक', 2),
#  ('जुळणारा', 2),
#  ('उचित', 2),
#  ('इष्ट', 2),
#  ('अनुकूलता', 2),
#  ('माळ', 2),
#  ('अनुग्रह', 2),
#  ('प्रसाद', 2),
#  ('लोभ', 5),
#  ('उपदेश', 2),
#  ('दीक्षा', 2),
#  ('प्रोत्साहन', 2),
#  ('अनुचित', 4),
#  ('अप्रशस्त', 4),
#  ('अप्रस्तुत', 2),
#  ('अशोभनीय', 2),
#  ('अशिष्ट', 4),
#  ('असभ्य', 5),
#  ('अश्लील', 5),
#  ('ग्राम्य', 4),
#  ('अप्रासंगिक', 2),
#  ('अप्रयोजक', 3),
#  ('असंबद्ध', 3),
#  ('चूक', 4),
#  ('अन्याय्य', 2),
#  ('गैर', 4),
#  ('गैरलागू', 2),
#  ('गैरवाजवी', 2),
#  ('विशोभित', 2),
#  ('विपरीत', 2),
#  ('वाईट', 2),
#  ('अन्यायकारक', 2),
#  ('अश्लाघ्य', 3),
#  ('सदभिरुचिहीन', 2),
#  ('अनुनय', 4),
#  ('आराधना', 4),
#  ('मनधरणी', 4),
#  ('विनवणी', 3),
#  ('प्रार्थना', 4),
#  ('प्रियाराधन', 2),
#  ('प्रणयाराधन', 2),
#  ('खुशामत', 2),
#  ('लुप्त', 2),
#  ('उणीव', 3),
#  ('अनुबंध', 2),
#  ('धागादोरा', 2),
#  ('आकर्षण', 4),
#  ('स्नेह', 2),
#  ('अनुसंधान', 3),
#  ('जाणीव', 2),
#  ('परामर्श', 2),
#  ('तयारी', 2),
#  ('खुशी', 2),
#  ('अनुज्ञा', 2),
#  ('मोकळीक', 2),
#  ('पसंती', 2),
#  ('मोहित', 2),
#  ('अनुरक्ती', 3),
#  ('आसक्ती', 4),
#  ('प्रीती', 2),
#  ('प्रेम', 5),
#  ('आवड', 5),
#  ('मोहिनी', 2),
#  ('आतुरता', 3),
#  ('युक्त', 2),
#  ('पात्र', 2),
#  ('वर्णन', 3),
#  ('कथन', 2),
#  ('तर्जुमा', 2),
#  ('अनुशासन', 2),
#  ('आज्ञा', 2),
#  ('आदेश', 2),
#  ('कायदा', 2),
#  ('अभिषेक', 2),
#  ('उपासना', 2),
#  ('जप', 2),
#  ('स्थापना', 3),
#  ('योजना', 3),
#  ('बेत', 3),
#  ('धोरण', 2),
#  ('भान', 2),
#  ('तजवीज', 3),
#  ('भिन्न', 3),
#  ('अमोज', 2),
#  ('अनैतिक', 3),
#  ('अननुभूत', 3),
#  ('परका', 2),
#  ('अश्रुत', 2),
#  ('खाद्य', 2),
#  ('भक्ष्य', 3),
#  ('दमदमीत', 2),
#  ('वेगळा', 2),
#  ('निराळा', 2),
#  ('आगळा', 2),
#  ('अलिप्त', 2),
#  ('विसंगत', 3),
#  ('जोडीचा', 2),
#  ('विचक्षणा', 2),
#  ('पूसतपास', 2),
#  ('पाहणी', 2),
#  ('परीक्षण', 3),
#  ('अप्रतिष्ठा', 2),
#  ('बदनामी', 2),
#  ('मानहानी', 2),
#  ('मानखंडना', 2),
#  ('नाचक्की', 2),
#  ('बेअब्रू', 2),
#  ('काळोखी', 2),
#  ('लोकापवाद', 2),
#  ('पोटशूळ', 2),
#  ('पोटदुखी', 2),
#  ('निंदानालस्ती', 2),
#  ('अवहेलना', 2),
#  ('विकृती', 2),
#  ('विकार', 2),
#  ('विचलन', 2),
#  ('अधिक्षेप', 3),
#  ('दोषार्ह', 2),
#  ('अपराध', 3),
#  ('दोष', 3),
#  ('आगळीक', 2),
#  ('कसूर', 2),
#  ('प्रमाद', 2),
#  ('सत्यापलाप', 2),
#  ('खोटेपणा', 2),
#  ('विपर्यास', 2),
#  ('ठपका', 2),
#  ('exception', 2),
#  ('अभद्र', 5),
#  ('ओंगळ', 3),
#  ('बीभत्स', 3),
#  ('दुर्लक्षण', 2),
#  ('कुलक्षण', 2),
#  ('अपशकुनी', 3),
#  ('अनिष्टसूचक', 3),
#  ('ominous', 2),
#  ('पीडा', 2),
#  ('बाधा', 2),
#  ('उपद्रव', 2),
#  ('बिघाड', 2),
#  ('नवलाई', 2),
#  ('कौतुक', 3),
#  ('इच्छा', 6),
#  ('आकांक्षा', 4),
#  ('कांक्षा', 4),
#  ('वांछा', 2),
#  ('आशा', 4),
#  ('उमेद', 4),
#  ('मागणी', 3),
#  ('expectation', 2),
#  ('desire', 4),
#  ('अप्रचलित', 2),
#  ('vulgar', 2),
#  ('अप्रसन्न', 2),
#  ('नाराज', 2),
#  ('नाखूश', 2),
#  ('रुष्ट', 2),
#  ('इतराजी', 4),
#  ('गैरमर्जी', 2),
#  ('नापसंत', 2),
#  ('तापदायक', 2),
#  ('असंतोष', 4),
#  ('नाराजी', 3),
#  ('अवकृपा', 3),
#  ('द्वेष', 2),
#  ('चीड', 2),
#  ('गप्प', 2),
#  ('बोंब', 2),
#  ('अविरोध', 2),
#  ('वादातीत', 2),
#  ('निर्विवाद', 2),
#  ('unopposed', 2),
#  ('मौन', 2),
#  ('चिप्प', 2),
#  ('मुग्ध', 2),
#  ('मानमान्यता', 2),
#  ('नाव', 2),
#  ('दबदबा', 2),
#  ('sinister', 2),
#  ('पोकळी', 2),
#  ('उणेपणा', 2),
#  ('अभिजन', 2),
#  ('प्रतिष्ठित', 2),
#  ('सन्मान्य', 2),
#  ('स्तुती', 2),
#  ('आनंदप्रदर्शन', 2),
#  ('आविर्भाव', 3),
#  ('हावभाव', 2),
#  ('मुद्रा', 2),
#  ('अंगविक्षेप', 2),
#  ('हातवारे', 2),
#  ('अवतार', 4),
#  ('acting', 2),
#  ('अभिनिवेश', 3),
#  ('नेट', 3),
#  ('आवेश', 4),
#  ('जोम', 3),
#  ('जोश', 2),
#  ('आवेग', 3),
#  ('चेव', 3),
#  ('उत्साह', 6),
#  ('निर्धार', 2),
#  ('चैतन्य', 4),
#  ('जिद्द', 3),
#  ('ईर्षा', 3),
#  ('तडफ', 2),
#  ('vigour', 2),
#  ('अभिन्न', 2),
#  ('समाईक', 2),
#  ('अभिप्राय', 2),
#  ('अर्थ', 2),
#  ('सार', 3),
#  ('सारांश', 3),
#  ('उद्देश', 2),
#  ('मनोगत', 2),
#  ('मर्म', 2),
#  ('विचार', 2),
#  ('मानस', 2),
#  ('मनसुबा', 2),
#  ('शेरा', 2),
#  ('अहवाल', 3),
#  ('अहंता', 3),
#  ('अहंभाव', 2),
#  ('अहंकार', 2),
#  ('अहंपणा', 2),
#  ('ताठा', 2),
#  ('तोरा', 2),
#  ('ऐट', 2),
#  ('आत्मसंतुष्टता', 2),
#  ('तेजस्विता', 2),
#  ('गर्विष्ठ', 2),
#  ('अस्मिता', 2),
#  ('स्वाभिमान', 2),
#  ('अभिलाषा', 3),
#  ('लालसा', 4),
#  ('तृष्णा', 4),
#  ('वासना', 4),
#  ('कामना', 2),
#  ('कामातुरता', 2),
#  ('हाव', 3),
#  ('avarice', 2),
#  ('अभिवंदन', 2),
#  ('नमन', 4),
#  ('अभ्युत्थान', 3),
#  ('मानवंदना', 2),
#  ('सलामी', 3),
#  ('सत्कार', 2),
#  ('अभिव्यक्ती', 2),
#  ('आविष्करण', 2),
#  ('आविष्कार', 3),
#  ('प्रकटन', 2),
#  ('प्रदर्शन', 4),
#  ('दर्शन', 2),
#  ('मांडणी', 4),
#  ('निवेदन', 2),
#  ('आलेखन', 2),
#  ('expression', 2),
#  ('अभीष्टचिंतन', 2),
#  ('शुभचिंतन', 2),
#  ('शुभेच्छा', 2),
#  ('सदिच्छा', 2),
#  ('आशीर्वाद', 2),
#  ('अभ्यर्थना', 2),
#  ('आळवणी', 2),
#  ('विनंती', 2),
#  ('मिनतवारी', 2),
#  ('याचना', 3),
#  ('request', 2),
#  ('अभ्युदय', 2),
#  ('उदय', 2),
#  ('अक्षय्य', 2),
#  ('अक्षर', 3),
#  ('चिरंजीव', 2),
#  ('चिरायू', 2),
#  ('अवीट', 2),
#  ('अमुक', 2),
#  ('अमूर्त', 2),
#  ('अव्यक्त', 3),
#  ('तीक्ष्ण', 2),
#  ('आडरान', 2),
#  ('आडदांड', 2),
#  ('uncivilised', 2),
#  ('पचपचीत', 2),
#  ('घोटाळ्याचे', 2),
#  ('अराजक', 3),
#  ('अशांतता', 4),
#  ('चळवळ', 4),
#  ('अस्थैर्य', 6),
#  ('विस्कळीत', 2),
#  ('चढाईखोर', 2),
#  ('भांडखोर', 2),
#  ('सत्त्व', 3),
#  ('धनदौलत', 2),
#  ('बचत', 2),
#  ('बळी', 2),
#  ('sacrifice', 2),
#  ('चटोर', 2),
#  ('चहाटळ', 2),
#  ('बाष्कळ', 2),
#  ('वात्रट', 2),
#  ('शोभा', 4),
#  ('शृंगार', 2),
#  ('रंगेल', 2),
#  ('विलासी', 2),
#  ('निर्मळ', 2),
#  ('विराम', 2),
#  ('सवड', 2),
#  ('फुरसत', 3),
#  ('वेळ', 2),
#  ('उशीर', 3),
#  ('काळ', 3),
#  ('समय', 2),
#  ('अवसर', 2),
#  ('अप्रसन्नता', 2),
#  ('राग', 2),
#  ('गुंडाळणे', 2),
#  ('ठोक', 2),
#  ('गुरू', 2),
#  ('डामडौल', 3),
#  ('थाटमाट', 2),
#  ('भपका', 2),
#  ('देखावा', 3),
#  ('दिमाख', 2),
#  ('आव', 5),
#  ('pomp', 2),
#  ('show', 2),
#  ('मूर्ती', 2),
#  ('स्वरूप', 4),
#  ('चित्त', 2),
#  ('उसंत', 2),
#  ...]

# %%
mydict = defaultdict(list)
for el in c.items():
    if el[1] > 1:
        for i in theList:
            for x in i:
                if x == el[0]:
                    mydict[x].append(i)

# %%
for k, v in mydict.items():
    mylen = 0
    myl3 = list()
    for i in v:
        mylen = mylen + len(i)
        myl3.append(i[0])
    print(k, mylen, myl3, len(myl3) > len(set(myl3)))
# Out:
# अकटोविकट 43 ['अकटोविकट', 'अचाट'] False
# अगडबंब 33 ['अकटोविकट', 'अवजड'] False
# प्रचंड 103 ['अकटोविकट', 'अगाध', 'अचाट', 'अतिशय'] False
# अचाट 156 ['अकटोविकट', 'अचाट', 'अतिशय', 'अद्भुत', 'आश्चर्य'] False
# अफाट 124 ['अकटोविकट', 'अगाध', 'अचाट', 'अतिशय', 'अनंत', 'अफाट'] False
# विशाल 48 ['अकटोविकट', 'अचाट', 'अफाट'] False
# भव्य 43 ['अकटोविकट', 'अचाट'] False
# अवजड 33 ['अकटोविकट', 'अवजड'] False
# बोजड 33 ['अकटोविकट', 'अवजड'] False
# अकरणीय 53 ['अकरणीय', 'अनुचित', 'अवैध'] False
# अविहित 29 ['अकरणीय', 'अवैध', 'असंमत'] False
# निषिद्ध 23 ['अकरणीय', 'निषिद्ध', 'असंमत'] False
# त्याज्य 56 ['अकरणीय', 'अनुचित', 'असंमत'] False
# अयोग्य 69 ['अकरणीय', 'अनुचित', 'अन्यायकारक', 'अप्रयोजक'] False
# बेकायदेशीर 43 ['अकरणीय', 'अन्यायकारक', 'अपराध', 'अवैध'] False
# द्वाड 43 ['अकरुण', 'अगोचर', 'अर्वाच्य'] False
# कठोर 33 ['अकरुण', 'असह्य'] False
# निष्ठुर 24 ['अकरुण', 'अनुदार'] False
# निर्दय 56 ['अकरुण', 'अत्याचार', 'अनुदार', 'अमानुष'] False
# क्रूर 65 ['अकरुण', 'अघोरी', 'अमानुष', 'असुर'] False
# अकल्पित 25 ['अकल्पित', 'अकस्मात', 'अनाहूत'] False
# अनपेक्षित 25 ['अकल्पित', 'अकस्मात', 'अनाहूत'] False
# आकस्मिक 24 ['अकल्पित', 'अनाहूत', 'अहेतुक'] False
# आगंतुक 27 ['अकल्पित', 'अतिथी', 'अनाहूत'] False
# अनाहूत 13 ['अकल्पित', 'अनाहूत'] False
# अकस्मात 25 ['अकल्पित', 'अकस्मात', 'अभावितपणे'] False
# अकल्याण 26 ['अकल्याण', 'अपाय'] False
# हानी 54 ['अकल्याण', 'अपघात', 'अपयश', 'अपाय'] False
# नुकसान 45 ['अकल्याण', 'अपयश', 'अपाय'] False
# अपाय 26 ['अकल्याण', 'अपाय'] False
# अपकार 26 ['अकल्याण', 'अपाय'] False
# अशुभ 67 ['अकल्याण', 'अपवित्र', 'अपशकुनी', 'अभद्र', 'अशुभ'] False
# अमंगल 44 ['अकल्याण', 'अपवित्र', 'अशुभ'] False
# अनिष्ट 76 ['अकल्याण', 'अनुचित', 'अभद्र', 'अशुभ'] False
# अपघात 21 ['अकस्मात', 'अपघात'] False
# योगायोग 39 ['अकस्मात', 'अनुबंध', 'अपघात'] False
# अकारण 22 ['अकारण', 'अहेतुक'] False
# विनाकारण 22 ['अकारण', 'अहेतुक'] False
# निरुद्देश 19 ['अकारण', 'अनौपचारिक'] False
# अहेतुक 22 ['अकारण', 'अहेतुक'] False
# व्यर्थ 61 ['अकारण', 'अनुचित', 'असार'] False
# निरर्थक 24 ['अकारण', 'असार'] False
# दुर्भिक्ष 59 ['अकाल', 'अभाव'] False
# वाण 80 ['अकाल', 'अभाव', 'आहेर'] False
# चणचण 59 ['अकाल', 'अभाव'] False
# गरीब 39 ['अकिंचन', 'आज्ञाधारक'] False
# नंगा 39 ['अकिंचन', 'अनावृत'] False
# अभाव 70 ['अकिंचन', 'अभाव'] False
# अंकित 23 ['अंकित', 'आधीन'] False
# अंकुर 98 ['अंकुर', 'आरंभ'] False
# मोड 61 ['अंकुर', 'अर्थ'] False
# लागणे 26 ['अंकुरणे', 'आढळणे'] False
# अंकुश 29 ['अंकुश', 'अणकुची'] False
# ताबा 42 ['अंकुश', 'अधिकार'] False
# हुकमत 58 ['अंकुश', 'अधिकार', 'अनुशासन'] False
# नियंत्रण 119 ['अंकुश', 'अटकाव', 'अधिकार', 'अनुशासन'] False
# निर्बंध 109 ['अंकुश', 'अट', 'अटकाव', 'अनुशासन', 'आडपडदा'] False
# मर्यादा 86 ['अंकुश', 'अटकाव', 'आडपडदा'] False
# सहज 58 ['अकृत्रिम', 'अनौपचारिक', 'अहेतुक', 'आपोआप'] False
# निसर्गदत्त 35 ['अकृत्रिम', 'आनुवंशिक'] False
# स्वयंभू 40 ['अकृत्रिम', 'अनादी'] False
# उपजत 35 ['अकृत्रिम', 'आनुवंशिक'] False
# स्वयंस्फूर्त 36 ['अकृत्रिम', 'अहेतुक'] False
# शुद्ध 110 ['अकृत्रिम', 'अट्टल', 'अनघ', 'अलिप्त', 'अव्यंग', 'अक्षत'] False
# अस्सल 56 ['अकृत्रिम', 'अट्टल'] False
# खरा 56 ['अकृत्रिम', 'अट्टल'] False
# निष्पाप 42 ['अकृत्रिम', 'अनघ'] False
# निष्कपट 42 ['अकृत्रिम', 'अनघ'] False
# अल्लड 130 ['अकृत्रिम', 'अजाण', 'अल्पवयस्क'] False
# निर्हेतुक 36 ['अकृत्रिम', 'अहेतुक'] False
# सरळ 43 ['अकृत्रिम', 'असंदिग्ध'] False
# अक्कडबाज 25 ['अक्कडबाज', 'अलबेला'] False
# छकडा 72 ['अक्कडबाज', 'आकर्षक'] False
# अलबेला 25 ['अक्कडबाज', 'अलबेला'] False
# बुद्धी 109 ['अक्कल', 'इच्छा'] False
# आकलनशक्ती 48 ['अक्कल', 'आवाका'] False
# दु:स्थिती 38 ['अक्काबाई', 'अवस्था'] False
# अवदशा 46 ['अक्काबाई', 'अधोगती'] False
# आपत्ती 72 ['अक्काबाई', 'अटकाव'] False
# दुर्बुद्धी 28 ['अक्काबाई', 'अविचार'] False
# अखंड 157 ['अखंड', 'अमर', 'अविभक्त', 'अव्यंग', 'अस्खलित'] False
# अखंडित 105 ['अखंड', 'अमर'] False
# अभंग 122 ['अखंड', 'अमर', 'अस्खलित'] False
# अत्रुटित 108 ['अखंड', 'अविभक्त', 'अस्खलित'] False
# अस्खलित 94 ['अखंड', 'अस्खलित'] False
# अभेद्य 100 ['अखंड', 'अजिंक्य', 'अमोघ'] False
# अविभाज्य 115 ['अखंड', 'अभिन्न', 'अविभक्त'] False
# सलग 94 ['अखंड', 'अस्खलित'] False
# सगळा 110 ['अखंड', 'अवघा'] False
# सबंध 124 ['अखंड', 'अवघा', 'अविभक्त'] False
# अख्खा 91 ['अखंड', 'अविभक्त'] False
# एक 105 ['अखंड', 'अजोड'] False
# एकसंध 108 ['अखंड', 'अविभक्त', 'अस्खलित'] False
# अक्षत 105 ['अखंड', 'अनघ', 'अक्षत'] False
# अतूट 120 ['अखंड', 'अचल', 'अवीट'] False
# अवघा 110 ['अखंड', 'अवघा'] False
# पूर्ण 110 ['अखंड', 'अवघा'] False
# संपूर्ण 131 ['अखंड', 'अवघा', 'अव्यंग'] False
# समग्र 110 ['अखंड', 'अवघा'] False
# अविभक्त 115 ['अखंड', 'अभिन्न', 'अविभक्त'] False
# अविरत 171 ['अखंड', 'अखंड', 'अस्खलित'] True
# निरंतर 182 ['अखंड', 'अखंड', 'अमर'] True
# अव्याहत 154 ['अखंड', 'अखंड'] True
# अविनाशी 105 ['अखंड', 'अमर'] False
# अनश्वर 117 ['अखंड', 'अमर', 'अवीट'] False
# शाश्वत 133 ['अखंड', 'अनंत', 'अमर', 'अवीट'] False
# चिर 105 ['अखंड', 'अमर'] False
# चिरंतन 120 ['अखंड', 'अनादी', 'अमर'] False
# चिरस्थायी 117 ['अखंड', 'अमर', 'अवीट'] False
# कायम 136 ['अखंड', 'अचल', 'अमर'] False
# अक्षय 121 ['अखंड', 'अनंत', 'अमर'] False
# अनंत 133 ['अखंड', 'अनंत', 'अमर', 'अमेय'] False
# सतत 94 ['अखंड', 'अस्खलित'] False
# नित्य 136 ['अखंड', 'अचल', 'अमर'] False
# अनिरुद्ध 107 ['अखंड', 'अनियंत्रित'] False
# अप्रतिहत 124 ['अखंड', 'अनियंत्रित', 'अस्खलित'] False
# बेचव 28 ['अखाद्य', 'अरसिक'] False
# अखेर 86 ['अखेर', 'अंत'] False
# शेवट 105 ['अखेर', 'अग्र', 'अंत'] False
# अंत 133 ['अखेर', 'अखेर', 'अंत'] True
# समाप्ती 86 ['अखेर', 'अंत'] False
# परिसमाप्ती 86 ['अखेर', 'अंत'] False
# सांगता 86 ['अखेर', 'अंत'] False
# पूर्णविराम 86 ['अखेर', 'अंत'] False
# अस्त 86 ['अखेर', 'अंत'] False
# लय 86 ['अखेर', 'अंत'] False
# विलय 86 ['अखेर', 'अंत'] False
# विसर्जन 86 ['अखेर', 'अंत'] False
# बरखास्ती 86 ['अखेर', 'अंत'] False
# बोळवण 86 ['अखेर', 'अंत'] False
# गती 103 ['अखेर', 'आवेग'] False
# गत 74 ['अखेर', 'अवस्था'] False
# नाश 134 ['अखेर', 'अंत', 'अधोगती', 'अनर्थ'] False
# टोक 66 ['अखेर', 'अग्र'] False
# शेपूट 68 ['अखेर', 'अवशिष्ट'] False
# कड 86 ['अखेर', 'अंत'] False
# सीमा 108 ['अखेर', 'अंत', 'अतिरेक'] False
# परिसीमा 108 ['अखेर', 'अंत', 'अतिरेक'] False
# हद्द 108 ['अखेर', 'अंत', 'अतिरेक'] False
# कळस 127 ['अखेर', 'अग्र', 'अंत', 'अतिरेक'] False
# उपसंहार 86 ['अखेर', 'अंत'] False
# आटोपणे 67 ['अखेर', 'आटोपणे'] False
# अवयव 47 ['अंग', 'अंश'] False
# विभाग 64 ['अंग', 'अध्याय', 'अंश'] False
# घटक 47 ['अंग', 'अंश'] False
# हिस्सा 47 ['अंग', 'अंश'] False
# शाखा 47 ['अंग', 'अंश'] False
# कल 108 ['अंग', 'इच्छा'] False
# प्रवृत्ती 108 ['अंग', 'इच्छा'] False
# क्षमता 105 ['अंग', 'अधिकार', 'अवसान', 'आवाका'] False
# कुळागर 47 ['अंगण', 'अरण्य'] False
# फड 83 ['अंगण', 'अड्डा', 'अड्डा'] True
# असहाय 29 ['अगतिक', 'अनाथ'] False
# निराधार 37 ['अगतिक', 'अधांतरी', 'अनाथ'] False
# दिङ्मूढ 91 ['अगतिक', 'अबोल', 'आश्चर्य'] False
# अगत्य 156 ['अगत्य', 'आग्रह', 'आदर', 'आपुलकी', 'आस्था'] False
# आस्था 112 ['अगत्य', 'अनुकंपा', 'आच', 'आपुलकी', 'आस्था'] False
# आपुलकी 65 ['अगत्य', 'आपुलकी', 'आस्था'] False
# सद्भाव 105 ['अगत्य', 'आदर', 'आस्था'] False
# कळकळ 112 ['अगत्य', 'अनुकंपा', 'आच', 'आपुलकी', 'आस्था'] False
# पाहुणचार 82 ['अगत्य', 'आदर'] False
# स्वागत 82 ['अगत्य', 'आदर'] False
# आगतस्वागत 82 ['अगत्य', 'आदर'] False
# आग्रह 49 ['अगत्य', 'आग्रह'] False
# पानसुपारी 82 ['अगत्य', 'आदर'] False
# अत्तरगुलाब 82 ['अगत्य', 'आदर'] False
# मानसन्मान 82 ['अगत्य', 'आदर'] False
# शिष्टाचार 41 ['अगत्य', 'आहेर'] False
# कदर 127 ['अगत्य', 'आदर', 'आपुलकी', 'आस्था'] False
# अवश्य 37 ['अगत्य', 'आवश्यक'] False
# अगम्य 25 ['अगम्य', 'अप्राप्य'] False
# अतर्क्य 52 ['अगम्य', 'अघटित', 'अचाट'] False
# अज्ञेय 29 ['अगम्य', 'अमेय'] False
# अगाध 25 ['अगम्य', 'अगाध'] False
# कल्पनातीत 91 ['अगम्य', 'अचाट', 'अतिशय'] False
# गूढ 69 ['अगम्य', 'अनोळखी', 'अव्यक्त', 'अस्पष्ट'] False
# गहन 25 ['अगम्य', 'अगाध'] False
# दुर्बोध 59 ['अगम्य', 'अनिश्चित', 'अस्पष्ट'] False
# दुर्गम 33 ['अगम्य', 'अशक्य'] False
# गुप्त 31 ['अगम्य', 'अव्यक्त'] False
# अलभ्य 41 ['अगम्य', 'अप्राप्य', 'अशक्य'] False
# अप्राप्य 41 ['अगम्य', 'अप्राप्य', 'अशक्य'] False
# बांधा 35 ['अंगयष्टी', 'आकार'] False
# हाड 20 ['अंगयष्टी', 'अस्थी'] False
# घाट 49 ['अंगयष्टी', 'आकार', 'आव'] False
# ठेवण 35 ['अंगयष्टी', 'आकार'] False
# गोंधळ 152 ['अगाजा', 'अनर्थ', 'अराजक', 'अशांतता', 'अस्थैर्य'] False
# गडबड 139 ['अगाजा', 'अराजक', 'अशांतता', 'अस्थैर्य'] False
# धुमाळी 68 ['अगाजा', 'अराजक'] False
# थैमान 50 ['अगाजा', 'अनर्थ'] False
# दंगा 91 ['अगाजा', 'अशांतता'] False
# खळबळ 120 ['अगाजा', 'अशांतता', 'असंतोष'] False
# धुमश्चक्री 122 ['अगाजा', 'अराजक', 'अशांतता'] False
# बोभाटा 57 ['अगाजा', 'अफवा'] False
# अमर्याद 147 ['अगाध', 'अचाट', 'अतिशय', 'अतिशयोक्त', 'अनंत', 'अनियंत्रित', 'अमेय'] False
# स्वीकृती 41 ['अंगीकार', 'अनुमती'] False
# संमती 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# अनुमती 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# मान्यता 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# रुकार 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# मंजुरी 41 ['अंगीकार', 'अनुमती'] False
# कबुली 41 ['अंगीकार', 'अनुमती'] False
# कवटाळणे 59 ['अंगीकार', 'आलिंगन'] False
# अगोचर 31 ['अगोचर', 'अर्वाच्य'] False
# खट्याळ 48 ['अगोचर', 'अर्वाच्य', 'आचरट'] False
# खोडकर 31 ['अगोचर', 'अर्वाच्य'] False
# व्रात्य 32 ['अगोचर', 'आचरट'] False
# आगाऊ 39 ['अगोचर', 'आधी'] False
# बंड 100 ['अगोचर', 'अराजक', 'अशांतता'] False
# चावट 75 ['अगोचर', 'अर्वाच्य', 'अशिष्ट', 'आचरट'] False
# अर्वाच्य 98 ['अगोचर', 'अनियंत्रित', 'अपवित्र', 'अर्वाच्य', 'आचरट'] False
# होम 110 ['अग्नी', 'अनुष्ठान'] False
# चिता 151 ['अग्नी', 'अंत्येष्टी'] False
# भट्टी 119 ['अग्नी', 'अड्डा'] False
# दहन 151 ['अग्नी', 'अंत्येष्टी'] False
# दाह 190 ['अग्नी', 'अग्नी', 'आच'] True
# रखरख 104 ['अग्नी', 'आच'] False
# जळणे 116 ['अग्नी', 'असूया'] False
# धगधगणे 124 ['अग्नी', 'अशांत'] False
# भाजणे 172 ['अग्नी', 'अग्नी'] True
# अणकुची 37 ['अग्र', 'अणकुची'] False
# शिखर 58 ['अग्र', 'अंत'] False
# प्रथमस्थान 33 ['अग्र', 'आघाडी'] False
# आघाडी 33 ['अग्र', 'आघाडी'] False
# बिनी 33 ['अग्र', 'आघाडी'] False
# प्रथम 64 ['अग्रगण्य', 'आद्य', 'आधी'] False
# पहिला 40 ['अग्रगण्य', 'आद्य'] False
# अध्वर्यू 44 ['अग्रगण्य', 'अध्यक्ष'] False
# धुरीण 44 ['अग्रगण्य', 'अध्यक्ष'] False
# प्रमुख 40 ['अग्रगण्य', 'आद्य'] False
# श्रेष्ठ 63 ['अग्रगण्य', 'अचाट', 'आगळा'] False
# सर्वश्रेष्ठ 56 ['अग्रगण्य', 'अजोड'] False
# परम 80 ['अग्रगण्य', 'अतिशय'] False
# लोकोत्तर 78 ['अग्रगण्य', 'अजोड', 'अद्भुत'] False
# थोर 41 ['अग्रगण्य', 'आगळा'] False
# निपुण 59 ['अग्रगण्य', 'अट्टल'] False
# अध्यक्ष 44 ['अग्रगण्य', 'अध्यक्ष'] False
# आद्य 40 ['अग्रगण्य', 'आद्य'] False
# विलक्षण 105 ['अघटित', 'अचाट', 'अद्भुत', 'अनोखा', 'आश्चर्य'] False
# चमत्कारिक 49 ['अघटित', 'अद्भुत', 'अनोळखी'] False
# चमत्कृतिपूर्ण 35 ['अघटित', 'अद्भुत'] False
# विचित्र 35 ['अघटित', 'अद्भुत'] False
# अद्भुत 105 ['अघटित', 'अचाट', 'अद्भुत', 'अनोखा', 'आश्चर्य'] False
# अभूतपूर्व 35 ['अघटित', 'अद्भुत'] False
# अजब 74 ['अघटित', 'अद्भुत', 'आश्चर्य'] False
# आश्चर्यकारक 35 ['अघटित', 'अद्भुत'] False
# असंभाव्य 29 ['अघटित', 'अशक्य'] False
# विस्तृत 26 ['अघळपघळ', 'अफाट'] False
# मोकळा 51 ['अघळपघळ', 'अनियंत्रित'] False
# खुला 60 ['अघळपघळ', 'अनियंत्रित', 'अबाधित'] False
# अघोरी 37 ['अघोरी', 'अमानुष'] False
# दुष्ट 103 ['अघोरी', 'अत्याचार', 'अधम', 'अनुदार', 'अभद्र'] False
# राक्षसी 37 ['अघोरी', 'अमानुष'] False
# सैतानी 70 ['अघोरी', 'अधम', 'अमानुष'] False
# पाशवी 56 ['अघोरी', 'अत्याचार', 'अमानुष'] False
# अमानुष 56 ['अघोरी', 'अत्याचार', 'अमानुष'] False
# रानटी 94 ['अघोरी', 'अत्याचार', 'अमानुष', 'असंस्कृत', 'असुर'] False
# जंगली 56 ['अघोरी', 'अरबट', 'असंस्कृत'] False
# भेसूर 37 ['अघोरी', 'अमानुष'] False
# भीषण 45 ['अघोरी', 'असह्य'] False
# दारुण 58 ['अघोरी', 'अमानुष', 'असह्य'] False
# घोर 45 ['अघोरी', 'असह्य'] False
# निंद्य 97 ['अघोरी', 'अधम', 'अप्रशस्त', 'अशिष्ट'] False
# गर्हणीय 61 ['अघोरी', 'अनुचित'] False
# अतिरेकी 50 ['अघोरी', 'अतिरेकी', 'अतिशयोक्त', 'आततायी'] False
# अमंगळ 44 ['अघोरी', 'अपवित्र'] False
# अपवित्र 44 ['अघोरी', 'अपवित्र'] False
# दु:सह 45 ['अघोरी', 'असह्य'] False
# अचंबा 45 ['अचंबा', 'आश्चर्य'] False
# नवल 45 ['अचंबा', 'आश्चर्य'] False
# विस्मय 45 ['अचंबा', 'आश्चर्य'] False
# आश्चर्य 53 ['अचंबा', 'अपूर्वाई', 'आश्चर्य'] False
# चमत्कार 45 ['अचंबा', 'आश्चर्य'] False
# अढळ 43 ['अचल', 'अवीट'] False
# निश्चित 49 ['अचल', 'असंदिग्ध'] False
# पक्का 62 ['अचल', 'अट्टल'] False
# स्तब्ध 69 ['अचल', 'अबोल'] False
# निमूट 69 ['अचल', 'अबोल'] False
# निश्चेष्ट 43 ['अचल', 'अचेतन'] False
# खंबीर 36 ['अचल', 'आग्रही'] False
# अलौकिक 72 ['अचाट', 'अजोड', 'अद्भुत'] False
# अपूर्व 53 ['अचाट', 'अद्भुत', 'अनोखा'] False
# असामान्य 72 ['अचाट', 'अजोड', 'अद्भुत'] False
# बेसुमार 74 ['अचाट', 'अतिशय'] False
# पराकोटीचा 34 ['अचाट', 'अनावर'] False
# अतिशय 74 ['अचाट', 'अतिशय'] False
# अचूक 49 ['अचूक', 'असंदिग्ध', 'अस्खलित'] False
# बिनचूक 31 ['अचूक', 'अस्खलित'] False
# निर्दोष 69 ['अचूक', 'अनघ', 'अव्यंग', 'अस्खलित'] False
# असंदिग्ध 32 ['अचूक', 'असंदिग्ध'] False
# तंतोतंत 30 ['अचूक', 'अनुकरण'] False
# विश्वसनीय 45 ['अचूक', 'अट्टल'] False
# अमोघ 37 ['अचूक', 'अजिंक्य', 'अमोघ'] False
# जड 109 ['अचेतन', 'अजाण', 'अवजड'] False
# अपेक्षा 169 ['अजमास', 'अपेक्षा', 'आकांक्षा', 'आशा', 'इच्छा'] False
# अंदाज 58 ['अजमास', 'आराखडा'] False
# अटकळ 48 ['अजमास', 'आशा'] False
# संशय 44 ['अजमास', 'अविश्वास', 'आक्षेप'] False
# शंका 81 ['अजमास', 'अढी', 'अनिश्चितता', 'अविश्वास', 'आक्षेप'] False
# मत 77 ['अजमास', 'अभिप्राय', 'अहवाल'] False
# कल्पना 69 ['अजमास', 'आभास', 'आशा'] False
# आराखडा 72 ['अजमास', 'आखणी', 'आराखडा'] False
# अजागळ 59 ['अजागळ', 'अरळ', 'अव्यवस्थित'] False
# अव्यवस्थित 100 ['अजागळ', 'अनियमित', 'अरळ', 'अराजक', 'अव्यवस्थित'] False
# अकुशल 122 ['अजागळ', 'अजाण', 'अननुभवी'] False
# भोंगळ 59 ['अजागळ', 'अरळ', 'अव्यवस्थित'] False
# गबाळग्रंथी 48 ['अजागळ', 'अव्यवस्थित'] False
# ध्यान 50 ['अजागळ', 'अवधान', 'अष्टांगयोग'] False
# अजाण 98 ['अजाण', 'अननुभवी'] False
# अज्ञान 130 ['अजाण', 'अल्पवयस्क', 'अज्ञान'] False
# अविद्य 107 ['अजाण', 'असंस्कृत'] False
# अनभ्यस्त 98 ['अजाण', 'अननुभवी'] False
# अडाणी 140 ['अजाण', 'अडमुठा', 'अविचारी', 'असंस्कृत'] False
# अप्रगल्भ 107 ['अजाण', 'असंस्कृत'] False
# अल्पबुद्धी 110 ['अजाण', 'अज्ञान'] False
# अननुभवी 98 ['अजाण', 'अननुभवी'] False
# अपक्व 109 ['अजाण', 'अननुभवी', 'अपक्व'] False
# अपरिपक्व 96 ['अजाण', 'अपक्व'] False
# असमंजस 105 ['अजाण', 'अविचारी'] False
# कोवळा 116 ['अजाण', 'अपक्व', 'अल्पवयस्क'] False
# कच्चा 96 ['अजाण', 'अपक्व'] False
# बाल 105 ['अजाण', 'अल्पवयस्क'] False
# आचरट 165 ['अजाण', 'अर्वाच्य', 'अविचारी', 'अशिष्ट', 'आचरट'] False
# कोरा 129 ['अजाण', 'अपक्व', 'असंस्कृत', 'अक्षत'] False
# व्यवहारशून्य 170 ['अजाण', 'अजाण'] True
# अशिक्षित 98 ['अजाण', 'अननुभवी'] False
# खेडवळ 107 ['अजाण', 'असंस्कृत'] False
# गावंढळ 107 ['अजाण', 'असंस्कृत'] False
# गावरान 107 ['अजाण', 'असंस्कृत'] False
# रानवट 107 ['अजाण', 'असंस्कृत'] False
# असंस्कृत 173 ['अजाण', 'अप्रशस्त', 'अरबट', 'अशिष्ट', 'असंस्कृत', 'असुर'] False
# अनागर 107 ['अजाण', 'असंस्कृत'] False
# अप्रबुद्ध 91 ['अजाण', 'अदूरदृष्टी'] False
# बुद्धिमंद 106 ['अजाण', 'अधू'] False
# मंद 109 ['अजाण', 'अस्पष्ट'] False
# मूर्ख 118 ['अजाण', 'अडमुठा', 'अविचारी'] False
# टोणपा 188 ['अजाण', 'आघात'] False
# बैलोबा 98 ['अजाण', 'अडमुठा'] False
# अजिंक्य 23 ['अजिंक्य', 'अमोघ'] False
# अजेय 23 ['अजिंक्य', 'अमोघ'] False
# दुर्दम्य 35 ['अजिंक्य', 'अनावर', 'अमोघ'] False
# अनावर 51 ['अजिंक्य', 'अनावर', 'अनियंत्रित'] False
# अगदी 42 ['अजिबात', 'अवघा'] False
# अनन्यसाधारण 50 ['अजोड', 'अद्भुत'] False
# सर्वोत्तम 43 ['अजोड', 'आदर्श'] False
# अट 76 ['अट', 'अटकाव', 'अपवाद'] False
# बंध 25 ['अट', 'अनुबंध'] False
# नियम 70 ['अट', 'अनुशासन', 'अष्टांगयोग', 'आदेश'] False
# अटक 69 ['अटक', 'अटकाव'] False
# मोहक 87 ['अटकर', 'अलबेला', 'आकर्षक'] False
# अटकाव 75 ['अटकाव', 'आडपडदा'] False
# अडथळा 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# अडसर 77 ['अटकाव', 'अडगळ'] False
# अडचण 109 ['अटकाव', 'अडगळ', 'अडचण', 'आणीबाणी'] False
# व्यत्यय 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# विघ्न 96 ['अटकाव', 'अडचण', 'अनर्थ'] False
# विक्षेप 91 ['अटकाव', 'अंतर'] False
# खंड 172 ['अटकाव', 'अंतर', 'अध्याय', 'अवकाश', 'अवधी', 'अंश'] False
# संकट 83 ['अटकाव', 'अडचण'] False
# कोंडी 76 ['अटकाव', 'अनिश्चितता'] False
# अंतराय 91 ['अटकाव', 'अंतर'] False
# हरकत 81 ['अटकाव', 'अपवाद', 'आक्षेप'] False
# तक्रार 73 ['अटकाव', 'आक्षेप'] False
# प्रतिबंध 122 ['अटकाव', 'अटकाव'] True
# विरोध 103 ['अटकाव', 'अंतर', 'आक्षेप'] False
# अटळ 25 ['अटळ', 'आवश्यक'] False
# अपरिहार्य 25 ['अटळ', 'आवश्यक'] False
# अनिवार्य 37 ['अटळ', 'अनावर', 'आवश्यक'] False
# आवश्यक 25 ['अटळ', 'आवश्यक'] False
# अत्यावश्यक 25 ['अटळ', 'आवश्यक'] False
# प्राप्त 25 ['अटळ', 'आवश्यक'] False
# भाग 57 ['अटळ', 'अंतर्भाव', 'अध्याय', 'अंश'] False
# कार्यक्षम 45 ['अट्टल', 'अमोघ'] False
# अर्क 45 ['अट्टल', 'अर्क'] False
# उत्कृष्ट 46 ['अट्टल', 'आदर्श'] False
# परिपूर्ण 100 ['अट्टल', 'अवघा', 'अव्यंग', 'आदर्श'] False
# गावणे 36 ['अडकणे', 'आढळणे'] False
# अडणे 44 ['अडकणे', 'अडकणे'] True
# निरुपयोगी 30 ['अडगळ', 'अप्रयोजक'] False
# रद्द 29 ['अडगळ', 'असंमत'] False
# गबाळ 40 ['अडगळ', 'अव्यवस्थित'] False
# पसारा 47 ['अडगळ', 'अराजक'] False
# त्रास 50 ['अडचण', 'आजार'] False
# उपाधी 72 ['अडचण', 'अभिधान', 'आजार'] False
# गोता 41 ['अडचण', 'अपयश'] False
# कमतरता 84 ['अडचण', 'अभाव', 'अवगुण'] False
# टंचाई 65 ['अडचण', 'अभाव'] False
# व्यापार 48 ['अडत', 'आचरण'] False
# हट्टी 18 ['अडमुठा', 'आग्रही'] False
# तळ 72 ['अड्डा', 'अंत'] False
# जागा 92 ['अड्डा', 'अवकाश', 'आलय'] False
# स्थान 75 ['अड्डा', 'अधिकार', 'अधिष्ठान'] False
# वसती 43 ['अड्डा', 'अस्तित्व'] False
# गट 59 ['अड्डा', 'अंश'] False
# अढी 52 ['अढी', 'असूया'] False
# ग्रह 74 ['अढी', 'अभिप्राय', 'आभास'] False
# कडवटपणा 51 ['अढी', 'असंतोष'] False
# पीळ 60 ['अढी', 'अभिमान'] False
# आकस 52 ['अढी', 'असूया'] False
# अदावत 52 ['अढी', 'असूया'] False
# असूया 52 ['अढी', 'असूया'] False
# घुस्सा 36 ['अढी', 'अवकृपा'] False
# अवसान 136 ['अंत', 'अवसान', 'आव', 'आवेग'] False
# प्रलय 83 ['अंत', 'अनर्थ', 'अराजक'] False
# संहार 52 ['अंत', 'अनर्थ'] False
# पडदा 76 ['अंत', 'अवगुंठन'] False
# निरोप 73 ['अंत', 'आदेश'] False
# पराभव 58 ['अंत', 'अपयश'] False
# पाडाव 58 ['अंत', 'अपयश'] False
# अंतर 68 ['अंतर', 'अवकाश', 'अवधी'] False
# न्यूनाधिक्य 60 ['अंतर', 'अंतर'] True
# पक्षपात 37 ['अंतर', 'अन्याय'] False
# मध्यांतर 54 ['अंतर', 'अवकाश'] False
# अवधी 68 ['अंतर', 'अवकाश', 'अवधी'] False
# टप्पा 56 ['अंतर', 'आवाका'] False
# पल्ला 56 ['अंतर', 'आवाका'] False
# धाव 53 ['अंतर', 'आकांक्षा'] False
# मध्यभाग 36 ['अंतरंग', 'अंश'] False
# अंतराळ 47 ['अंतराळ', 'अवकाश'] False
# आभाळ 36 ['अंतराळ', 'अभ्र'] False
# अवकाश 61 ['अंतराळ', 'अवकाश', 'अवधी'] False
# वातावरण 50 ['अंतराळ', 'अवस्था'] False
# मधला 27 ['अंतरिम', 'अंतर्गत'] False
# गुंतलेला 39 ['अंतर्गत', 'आनुषंगिक'] False
# संबंधित 109 ['अंतर्गत', 'आनुषंगिक', 'आप्त'] False
# अनुस्यूत 39 ['अंतर्गत', 'आनुषंगिक'] False
# शिरकाव 19 ['अंतर्भाव', 'अतिक्रमण'] False
# अतिक्रमण 34 ['अतिक्रमण', 'आक्रमण'] False
# लंघन 27 ['अतिक्रमण', 'अनशन'] False
# मर्यादातिक्रमण 28 ['अतिक्रमण', 'अपराध'] False
# अतिक्रम 45 ['अतिक्रमण', 'अपमान'] False
# आक्रमण 34 ['अतिक्रमण', 'आक्रमण'] False
# घुसखोरी 34 ['अतिक्रमण', 'आक्रमण'] False
# स्वारी 34 ['अतिक्रमण', 'आक्रमण'] False
# चाल 48 ['अतिक्रमण', 'आचरण'] False
# अमर्यादा 47 ['अतिप्रसंग', 'अपमान', 'आगळीक'] False
# अतिरेक 41 ['अतिरेक', 'अत्याचार'] False
# झोड 125 ['अतिरेक', 'आघात'] False
# तडाखा 237 ['अतिरेक', 'आघात', 'आवेग', 'आवेग'] True
# तीव्रता 78 ['अतिरेक', 'आवेग'] False
# प्रकोप 89 ['अतिरेक', 'अनर्थ', 'अशांतता'] False
# असीम 68 ['अतिशय', 'अनंत'] False
# अपार 68 ['अतिशय', 'अनंत'] False
# अपरिमित 80 ['अतिशय', 'अनंत', 'अमेय'] False
# अमित 80 ['अतिशय', 'अनंत', 'अमेय'] False
# अमाप 111 ['अतिशय', 'अनंत', 'अनेक', 'अमेय'] False
# अपरंपार 68 ['अतिशय', 'अनंत'] False
# आत्यंतिक 73 ['अतिशय', 'असह्य'] False
# भरमसाट 64 ['अतिशय', 'अनर्गल'] False
# अवाजवी 71 ['अतिशय', 'अतिशयोक्त', 'अन्यायकारक'] False
# वारेमाप 60 ['अतिशय', 'अद्वातद्वा'] False
# बेफाम 144 ['अतिशय', 'अनर्गल', 'अनावर', 'अनियंत्रित', 'अशांत'] False
# अनिवार 69 ['अतिशय', 'आवश्यक'] False
# विपुल 83 ['अतिशय', 'अनेक'] False
# पुष्कळ 83 ['अतिशय', 'अनेक'] False
# फार 63 ['अतिशय', 'अधिक'] False
# खूप 83 ['अतिशय', 'अनेक'] False
# चिकार 83 ['अतिशय', 'अनेक'] False
# मुबलक 83 ['अतिशय', 'अनेक'] False
# महामूर 60 ['अतिशय', 'आकंठ'] False
# उदंड 135 ['अतिशय', 'अतिशय', 'अनेक'] True
# तुफान 118 ['अतिशय', 'अनावर', 'अशांतता'] False
# कमालीचा 64 ['अतिशय', 'अनावर'] False
# पोकळ 20 ['अतिशयोक्त', 'असार'] False
# अवडंबर 39 ['अतिशयोक्ती', 'अवडंबर', 'आव'] False
# प्राचीन 19 ['अतीत', 'अप्रचलित'] False
# अतृप्त 52 ['अतृप्त', 'अधाशी', 'अप्रसन्न', 'असंतुष्ट'] False
# असमाधानी 25 ['अतृप्त', 'असंतुष्ट'] False
# असंतुष्ट 37 ['अतृप्त', 'अप्रसन्न', 'असंतुष्ट'] False
# असंतोषी 25 ['अतृप्त', 'असंतुष्ट'] False
# हावरट 23 ['अतृप्त', 'अधाशी'] False
# अधाशी 23 ['अतृप्त', 'अधाशी'] False
# लोभी 65 ['अतृप्त', 'अधाशी', 'आशाळभूत', 'इच्छुक'] False
# उमेदवार 57 ['अंतेवासी', 'अननुभवी', 'इच्छुक'] False
# शागीर्द 33 ['अंतेवासी', 'अनुचर'] False
# अनुयायी 33 ['अंतेवासी', 'अनुचर'] False
# मदतनीस 33 ['अंतेवासी', 'अनुचर'] False
# जुलूम 26 ['अत्याचार', 'अन्याय'] False
# जबरदस्ती 82 ['अत्याचार', 'अन्याय', 'आवेग'] False
# लाठीमार 122 ['अत्याचार', 'आघात'] False
# छळ 35 ['अत्याचार', 'अपाय'] False
# अस्थी 76 ['अंत्येष्टी', 'अस्थी'] False
# श्रद्धांजली 127 ['अंत्येष्टी', 'आदर'] False
# तर्पण 119 ['अंत्येष्टी', 'आनंद'] False
# सौहार्द 41 ['अदब', 'आपुलकी'] False
# आदर 81 ['अदब', 'आदर'] False
# सुसंस्कृतता 39 ['अदब', 'अभिरुची'] False
# डौल 59 ['अदब', 'आकार', 'आव'] False
# आर्जव 99 ['अदब', 'अनुनय', 'अभ्यर्थना', 'आग्रह'] False
# उतावळा 59 ['अदूरदृष्टी', 'अशांत', 'अस्थिर'] False
# अविचारी 38 ['अदूरदृष्टी', 'अविचारी', 'आततायी'] False
# अविवेकी 38 ['अदूरदृष्टी', 'अनर्गल', 'अविचारी'] False
# भविष्यमाण 40 ['अदृष्ट', 'आगामी'] False
# ईश्वरेच्छा 111 ['अदृष्ट', 'इच्छा'] False
# शासन 24 ['अद्दल', 'अनुशासन'] False
# ठोकर 111 ['अद्दल', 'आघात'] False
# नवलाईचा 31 ['अद्भुत', 'अनोखा'] False
# अनोखा 45 ['अद्भुत', 'अनोखा', 'अनोळखी'] False
# असाधारण 31 ['अद्भुत', 'अनोखा'] False
# सख्य 64 ['अद्वैत', 'अनुबंध', 'आपुलकी'] False
# एकवाक्यता 30 ['अद्वैत', 'अनुकूलता'] False
# अंध 33 ['अंध', 'अधू'] False
# हीन 53 ['अधम', 'अपवित्र'] False
# पापी 48 ['अधम', 'अभद्र'] False
# दुराचारी 45 ['अधम', 'अनैतिक'] False
# नीतिभ्रष्ट 45 ['अधम', 'अनैतिक'] False
# बदफैली 45 ['अधम', 'अनैतिक'] False
# अनीतिमान 45 ['अधम', 'अनैतिक'] False
# अधांतरी 26 ['अधांतरी', 'अनिश्चित'] False
# वर 26 ['अधांतरी', 'आशीर्वचन'] False
# हावरा 30 ['अधाशी', 'आशाळभूत'] False
# हपापलेला 30 ['अधाशी', 'आशाळभूत'] False
# आसक्त 23 ['अधाशी', 'अनुरक्त'] False
# अधिक 42 ['अधिक', 'अन्य'] False
# जास्त 24 ['अधिक', 'आगळा'] False
# जादा 42 ['अधिक', 'अन्य'] False
# आणखी 42 ['अधिक', 'अन्य'] False
# वरकड 32 ['अधिक', 'अवशिष्ट'] False
# अतिरिक्त 24 ['अधिक', 'आगळा'] False
# पूरक 20 ['अधिक', 'स्वादिष्ट'] False
# अधिष्ठान 87 ['अधिकार', 'अधिष्ठान', 'अस्तित्व', 'आलय'] False
# दावा 61 ['अधिकार', 'असूया'] False
# प्रभुत्व 47 ['अधिकार', 'अनुशासन'] False
# हुकूम 81 ['अधिकार', 'अनुशासन', 'आदेश'] False
# प्रभाव 57 ['अधिकार', 'आवाका'] False
# हुद्दा 53 ['अधिकार', 'अभिधान'] False
# प्रतिष्ठा 50 ['अधिकार', 'अब्रू'] False
# मान 93 ['अधिकार', 'आदर'] False
# अधिकारी 33 ['अधिकारी', 'अध्यक्ष'] False
# स्वामी 33 ['अधिकारी', 'अध्यक्ष'] False
# धनी 33 ['अधिकारी', 'अध्यक्ष'] False
# मालक 33 ['अधिकारी', 'अध्यक्ष'] False
# अधीक्षक 37 ['अधिकारी', 'अधीक्षक', 'अध्यक्ष'] False
# नियामक 33 ['अधिकारी', 'अध्यक्ष'] False
# बैठक 20 ['अधिवेशन', 'अधिष्ठान'] False
# आसन 24 ['अधिष्ठान', 'अष्टांगयोग'] False
# निवास 46 ['अधिष्ठान', 'आलय'] False
# अधिवास 46 ['अधिष्ठान', 'आलय'] False
# वास्तव्य 21 ['अधिष्ठान', 'अस्तित्व'] False
# वसतिस्थान 68 ['अधिष्ठान', 'आलय', 'आश्रम'] False
# अधीर 62 ['अधीर', 'अशांत', 'आर्त'] False
# आतुर 77 ['अधीर', 'अशांत', 'आर्त', 'आशाळभूत'] False
# उत्सुक 45 ['अधीर', 'आस्थेवाईक', 'इच्छुक'] False
# उत्कंठित 77 ['अधीर', 'अशांत', 'आर्त', 'आशाळभूत'] False
# उतावीळ 24 ['अधीर', 'आर्त'] False
# अस्वस्थ 46 ['अधीर', 'अशांत'] False
# बेचैन 46 ['अधीर', 'अशांत'] False
# परागती 54 ['अधोगती', 'अपयश'] False
# घट 78 ['अधोगती', 'अभाव'] False
# ढाळ 61 ['अधोगती', 'आकार'] False
# पीछेहाट 89 ['अधोगती', 'अधोगती', 'अपयश'] True
# कोसळणे 47 ['अधोगती', 'आदळणे'] False
# अध्ययन 84 ['अध्ययन', 'अन्वेषण', 'आवृत्ती'] False
# अभ्यास 45 ['अध्ययन', 'आवृत्ती'] False
# पठण 69 ['अध्ययन', 'अनुष्ठान', 'आवृत्ती'] False
# मनन 35 ['अध्ययन', 'समालोचन'] False
# चिंतन 46 ['अध्ययन', 'समालोचन', 'आढावा'] False
# परिशीलन 67 ['अध्ययन', 'अन्वेषण'] False
# संशोधन 67 ['अध्ययन', 'अन्वेषण'] False
# अन्वेषण 79 ['अध्ययन', 'अनुसंधान', 'अन्वेषण'] False
# आलोचन 50 ['अध्ययन', 'अवलोकन'] False
# सराव 45 ['अध्ययन', 'आवृत्ती'] False
# परिपाठ 63 ['अध्ययन', 'आचरण'] False
# पुनरावृत्ती 44 ['अध्ययन', 'अनुकरण'] False
# आवर्तन 45 ['अध्ययन', 'आवृत्ती'] False
# पाठांतर 45 ['अध्ययन', 'आवृत्ती'] False
# वाचणे 45 ['अध्ययन', 'असणे'] False
# सूत्रधार 29 ['अध्यक्ष', 'अभिनेता'] False
# अध्यात्म 47 ['अध्यात्म', 'आत्मा'] False
# आचार्य 38 ['अध्यापक', 'आचार्य'] False
# प्रवेश 99 ['अध्याय', 'आरंभ'] False
# पाठ 75 ['अध्याय', 'अनुष्ठान', 'आदेश'] False
# अनघ 28 ['अनघ', 'अक्षत'] False
# निष्कलंक 38 ['अनघ', 'अव्यंग'] False
# निर्लेप 22 ['अनघ', 'अलिप्त'] False
# पवित्र 49 ['अनघ', 'अव्यंग', 'अक्षत'] False
# स्वच्छ 56 ['अनघ', 'अव्यंग', 'असंदिग्ध'] False
# अमेय 59 ['अनंत', 'अनेक', 'अमेय'] False
# असंख्य 47 ['अनंत', 'अनेक'] False
# अगणित 47 ['अनंत', 'अनेक'] False
# अमर 56 ['अनंत', 'अमर', 'अवीट'] False
# नवा 57 ['अननुभवी', 'अनोखा', 'अनोळखी', 'अप्रसिद्ध', 'अक्षत'] False
# नवखा 27 ['अननुभवी', 'अनोळखी'] False
# संकोच 25 ['अनमान', 'आडपडदा'] False
# भीड 83 ['अनमान', 'अभाव', 'आग्रह'] False
# द्विधावृत्ती 26 ['अनमान', 'अनिश्चितता'] False
# उपेक्षा 23 ['अनमान', 'आबाळ'] False
# अनादर 43 ['अनमान', 'अपमान'] False
# अवज्ञा 23 ['अनमान', 'आज्ञाभंग'] False
# हयगय 78 ['अनमान', 'अनवधान', 'अपराध', 'अळंटळं', 'आबाळ'] False
# अनर्गल 59 ['अनर्गल', 'अविचारी', 'अशिष्ट'] False
# स्वैर 106 ['अनर्गल', 'अनियंत्रित', 'अनुचित', 'अशिष्ट'] False
# अप्रतिबंध 42 ['अनर्गल', 'अनियंत्रित'] False
# बेबंद 66 ['अनर्गल', 'अनियंत्रित', 'अव्यवस्थित'] False
# बेछूट 42 ['अनर्गल', 'अनियंत्रित'] False
# उद्दाम 30 ['अनर्गल', 'अरेराव'] False
# बेताल 42 ['अनर्गल', 'अनियंत्रित'] False
# अरिष्ट 22 ['अनर्थ', 'अपघात'] False
# विपत्ती 22 ['अनर्थ', 'अपघात'] False
# अनवधान 28 ['अनवधान', 'आबाळ'] False
# दुर्लक्ष 28 ['अनवधान', 'आबाळ'] False
# हेळसांड 28 ['अनवधान', 'आबाळ'] False
# गाफीलपणा 33 ['अनवधान', 'अविचार'] False
# निष्काळजीपणा 28 ['अनवधान', 'आबाळ'] False
# कर्तव्यच्युती 43 ['अनवधान', 'अपराध', 'आबाळ'] False
# ढिलाई 40 ['अनवधान', 'अळंटळं'] False
# दुराचार 30 ['अनाचार', 'दुर्वर्तन'] False
# दुराचरण 30 ['अनाचार', 'दुर्वर्तन'] False
# दुर्वर्तन 30 ['अनाचार', 'दुर्वर्तन'] False
# नीतिभ्रष्टता 49 ['अनाचार', 'आडमार्ग'] False
# अनीती 33 ['अनाचार', 'अन्याय'] False
# अधर्म 33 ['अनाचार', 'अन्याय'] False
# गैरव्यवहार 30 ['अनाचार', 'दुर्वर्तन'] False
# अनाथ 19 ['अनाथ', 'अनिकेत'] False
# गृहहीन 19 ['अनाथ', 'अनिकेत'] False
# अनिकेत 19 ['अनाथ', 'अनिकेत'] False
# मूळचा 27 ['अनादी', 'आद्य'] False
# हमी 29 ['अनामत', 'आश्वासन'] False
# हवाला 23 ['अनामत', 'अवलंबन'] False
# ठेव 59 ['अनामत', 'अर्थ'] False
# अनामिक 33 ['अनामिक', 'अनोळखी', 'अप्रसिद्ध'] False
# अज्ञात 33 ['अनामिक', 'अनोळखी', 'अप्रसिद्ध'] False
# अनोळखी 48 ['अनामिक', 'अनोळखी', 'अप्रसिद्ध', 'अलताभलता'] False
# अप्रसिद्ध 41 ['अनामिक', 'अनोळखी', 'अप्रचलित', 'अप्रसिद्ध'] False
# अप्रीती 72 ['अनावड', 'अप्रीती', 'अवकृपा', 'असंतोष'] False
# नावड 29 ['अनावड', 'अप्रीती'] False
# नाखुशी 72 ['अनावड', 'अप्रीती', 'अवकृपा', 'असंतोष'] False
# कंटाळा 39 ['अनावड', 'अळंटळं'] False
# नापसंती 70 ['अनावड', 'अप्रीती', 'असंतोष', 'आक्षेप'] False
# तिरस्कार 29 ['अनावड', 'अप्रीती'] False
# तिटकारा 29 ['अनावड', 'अप्रीती'] False
# आटोक्याबाहेरचा 20 ['अनावर', 'अप्राप्य'] False
# अनियंत्रित 42 ['अनावर', 'अनियंत्रित'] False
# बेलगाम 58 ['अनावर', 'अनियंत्रित', 'अर्वाच्य'] False
# भटक्या 19 ['अनिकेत', 'अस्थिर'] False
# वाह्यात 74 ['अनियंत्रित', 'अशिष्ट', 'आचरट'] False
# बेशिस्त 124 ['अनियंत्रित', 'अनियमित', 'अराजक', 'अव्यवस्थित', 'अस्थैर्य', 'आज्ञाभंग'] False
# मुक्त 39 ['अनियंत्रित', 'अबाधित'] False
# लहरी 55 ['अनियंत्रित', 'अनियमित', 'अस्थिर'] False
# बेकायदा 40 ['अनियंत्रित', 'अवैध'] False
# अनियमित 34 ['अनियमित', 'अव्यवस्थित'] False
# चंचल 63 ['अनियमित', 'अशांत', 'अस्थिर'] False
# अस्थिर 80 ['अनियमित', 'अशांत', 'अस्थिर', 'अस्थैर्य'] False
# अनिश्चित 42 ['अनिश्चित', 'अस्पष्ट'] False
# डळमळीत 33 ['अनिश्चित', 'अस्थिर'] False
# भ्रांत 61 ['अनिश्चित', 'अभाव'] False
# संदिग्ध 42 ['अनिश्चित', 'अस्पष्ट'] False
# मोघम 29 ['अनिश्चित', 'अरळ'] False
# अस्पष्ट 56 ['अनिश्चित', 'अव्यक्त', 'अस्पष्ट'] False
# पुसट 42 ['अनिश्चित', 'अस्पष्ट'] False
# साशंकता 23 ['अनिश्चितता', 'अविश्वास'] False
# संभ्रम 36 ['अनिश्चितता', 'आभास'] False
# पेचप्रसंग 25 ['अनिश्चितता', 'आणीबाणी'] False
# चलबिचल 86 ['अनिश्चितता', 'अशांतता', 'अस्थैर्य'] False
# अनुकंपा 52 ['अनुकंपा', 'आस्था'] False
# कृपा 54 ['अनुकंपा', 'अनुग्रह', 'आशीर्वचन'] False
# माया 96 ['अनुकंपा', 'आपुलकी', 'आभास', 'आसक्ती'] False
# ममता 75 ['अनुकंपा', 'आपुलकी', 'आसक्ती'] False
# मायाळूपणा 51 ['अनुकंपा', 'आपुलकी'] False
# नक्कल 38 ['अनुकरण', 'अभिनय'] False
# प्रतिकृती 33 ['अनुकरण', 'आवृत्ती'] False
# प्रत 33 ['अनुकरण', 'आवृत्ती'] False
# आवृत्ती 33 ['अनुकरण', 'आवृत्ती'] False
# नमुना 65 ['अनुकरण', 'आदर्श', 'आराखडा'] False
# बतावणी 54 ['अनुकरण', 'अभिनय', 'आविर्भाव'] False
# अभिनय 54 ['अनुकरण', 'अभिनय', 'आविर्भाव'] False
# सोंग 38 ['अनुकरण', 'अभिनय'] False
# विडंबन 38 ['अनुकरण', 'अभिनय'] False
# अनुकूल 31 ['अनुकूल', 'आश्वासक'] False
# आश्वासक 31 ['अनुकूल', 'आश्वासक'] False
# प्रोत्साहक 31 ['अनुकूल', 'आश्वासक'] False
# जुळणारा 35 ['अनुकूल', 'अनुरूप'] False
# उचित 35 ['अनुकूल', 'अनुरूप'] False
# इष्ट 35 ['अनुकूल', 'अनुरूप'] False
# अनुकूलता 30 ['अनुकूलता', 'अनुमती'] False
# माळ 45 ['अनुक्रम', 'अरण्य'] False
# अनुग्रह 25 ['अनुग्रह', 'आशीर्वचन'] False
# प्रसाद 25 ['अनुग्रह', 'आशीर्वचन'] False
# लोभ 93 ['अनुग्रह', 'अभिलाषा', 'असोशी', 'आकर्षण', 'आसक्ती'] False
# उपदेश 41 ['अनुग्रह', 'आदेश'] False
# दीक्षा 41 ['अनुग्रह', 'आदेश'] False
# प्रोत्साहन 22 ['अनुग्रह', 'आश्वासन'] False
# अनुचित 76 ['अनुचित', 'अन्यायकारक', 'अप्रयोजक', 'अप्रशस्त'] False
# अप्रशस्त 91 ['अनुचित', 'अप्रयोजक', 'अप्रशस्त', 'अशिष्ट'] False
# अप्रस्तुत 51 ['अनुचित', 'अप्रयोजक'] False
# अशोभनीय 51 ['अनुचित', 'अप्रयोजक'] False
# अशिष्ट 99 ['अनुचित', 'अप्रशस्त', 'अशिष्ट', 'असंस्कृत'] False
# असभ्य 111 ['अनुचित', 'अनैतिक', 'अप्रशस्त', 'अशिष्ट', 'असंस्कृत'] False
# अश्लील 109 ['अनुचित', 'अनैतिक', 'अपवित्र', 'अप्रशस्त', 'अशिष्ट'] False
# ग्राम्य 99 ['अनुचित', 'अप्रशस्त', 'अशिष्ट', 'असंस्कृत'] False
# अप्रासंगिक 51 ['अनुचित', 'अप्रयोजक'] False
# अप्रयोजक 64 ['अनुचित', 'अप्रयोजक', 'अप्रशस्त'] False
# असंबद्ध 79 ['अनुचित', 'अन्य', 'अरळ'] False
# चूक 72 ['अनुचित', 'अन्यायकारक', 'अपभ्रंश', 'अपराध'] False
# अन्याय्य 49 ['अनुचित', 'अन्यायकारक'] False
# गैर 94 ['अनुचित', 'अप्रशस्त', 'अशिष्ट', 'आचरट'] False
# गैरलागू 51 ['अनुचित', 'अप्रयोजक'] False
# गैरवाजवी 51 ['अनुचित', 'अप्रयोजक'] False
# विशोभित 51 ['अनुचित', 'अप्रयोजक'] False
# विपरीत 52 ['अनुचित', 'अभद्र'] False
# वाईट 52 ['अनुचित', 'अभद्र'] False
# अन्यायकारक 49 ['अनुचित', 'अन्यायकारक'] False
# अश्लाघ्य 77 ['अनुचित', 'अप्रशस्त', 'अशिष्ट'] False
# सदभिरुचिहीन 64 ['अनुचित', 'अशिष्ट'] False
# अनुनय 76 ['अनुनय', 'अभ्यर्थना', 'आराधना', 'मनधरणी'] False
# आराधना 92 ['अनुनय', 'अनुष्ठान', 'अभ्यर्थना', 'आराधना'] False
# मनधरणी 76 ['अनुनय', 'अभ्यर्थना', 'आराधना', 'मनधरणी'] False
# विनवणी 68 ['अनुनय', 'अभ्यर्थना', 'आराधना'] False
# प्रार्थना 92 ['अनुनय', 'अनुष्ठान', 'अभ्यर्थना', 'आराधना'] False
# प्रियाराधन 37 ['अनुनय', 'आराधना'] False
# प्रणयाराधन 37 ['अनुनय', 'आराधना'] False
# खुशामत 28 ['अनुनय', 'मनधरणी'] False
# लुप्त 23 ['अनुपस्थित', 'अप्रचलित'] False
# उणीव 68 ['अनुपस्थिती', 'अभाव', 'अवगुण'] False
# अनुबंध 30 ['अनुबंध', 'अनुसंधान'] False
# धागादोरा 57 ['अनुबंध', 'अन्वेषण'] False
# आकर्षण 71 ['अनुबंध', 'अनुरक्ती', 'आकर्षण', 'आमिष'] False
# स्नेह 40 ['अनुबंध', 'आपुलकी'] False
# अनुसंधान 69 ['अनुबंध', 'अनुसंधान', 'अन्वेषण'] False
# जाणीव 35 ['अनुभव', 'आभार'] False
# परामर्श 35 ['अनुभव', 'आढावा'] False
# तयारी 38 ['अनुमती', 'आखणी'] False
# खुशी 78 ['अनुमती', 'आनंद'] False
# अनुज्ञा 58 ['अनुमती', 'आदेश'] False
# मोकळीक 48 ['अनुमती', 'अवकाश'] False
# पसंती 111 ['अनुमती', 'इच्छा'] False
# मोहित 23 ['अनुरक्त', 'आधीन'] False
# अनुरक्ती 65 ['अनुरक्ती', 'आकर्षण', 'आसक्ती'] False
# आसक्ती 136 ['अनुरक्ती', 'अभिलाषा', 'आसक्ती', 'इच्छा'] False
# प्रीती 33 ['अनुरक्ती', 'आसक्ती'] False
# प्रेम 110 ['अनुरक्ती', 'आकर्षण', 'आपुलकी', 'आसक्ती', 'आस्था'] False
# आवड 171 ['अनुरक्ती', 'अभिरुची', 'आकर्षण', 'आस्था', 'इच्छा'] False
# मोहिनी 41 ['अनुरक्ती', 'आकर्षण'] False
# आतुरता 77 ['अनुरक्ती', 'अशांतता', 'असोशी'] False
# युक्त 30 ['अनुरूप', 'आशयघन'] False
# पात्र 28 ['अनुरूप', 'अभिनेता'] False
# वर्णन 60 ['अनुवाद', 'अभिव्यक्ती', 'अहवाल'] False
# कथन 38 ['अनुवाद', 'अभिव्यक्ती'] False
# तर्जुमा 44 ['अनुवाद', 'आराखडा'] False
# अनुशासन 50 ['अनुशासन', 'आदेश'] False
# आज्ञा 50 ['अनुशासन', 'आदेश'] False
# आदेश 50 ['अनुशासन', 'आदेश'] False
# कायदा 50 ['अनुशासन', 'आदेश'] False
# अभिषेक 39 ['अनुष्ठान', 'अभिषेक'] False
# उपासना 41 ['अनुष्ठान', 'आराधना'] False
# जप 41 ['अनुष्ठान', 'आवृत्ती'] False
# स्थापना 188 ['अनुष्ठान', 'आरंभ', 'आरंभ'] True
# योजना 60 ['अनुसंधान', 'आखणी', 'आराखडा'] False
# बेत 60 ['अनुसंधान', 'आखणी', 'आराखडा'] False
# धोरण 43 ['अनुसंधान', 'अभिप्राय'] False
# भान 25 ['अनुसंधान', 'अवधान'] False
# तजवीज 41 ['अनुसंधान', 'आखणी', 'इतमाम'] False
# भिन्न 87 ['अनेक', 'अन्य', 'असमान'] False
# अमोज 43 ['अनेक', 'अमेय'] False
# अनैतिक 51 ['अनैतिक', 'अन्यायकारक', 'अशिष्ट'] False
# अननुभूत 37 ['अनोखा', 'अनोळखी', 'अव्यक्त'] False
# परका 45 ['अनोळखी', 'अन्य'] False
# अश्रुत 24 ['अनोळखी', 'अप्रसिद्ध'] False
# खाद्य 28 ['अन्न', 'आमिष'] False
# भक्ष्य 41 ['अन्न', 'आमिष', 'आहुती'] False
# दमदमीत 17 ['स्वादिष्ट', 'आकंठ'] False
# वेगळा 44 ['अन्य', 'आगळा'] False
# निराळा 44 ['अन्य', 'आगळा'] False
# आगळा 44 ['अन्य', 'आगळा'] False
# अलिप्त 36 ['अन्य', 'अलिप्त'] False
# विसंगत 70 ['अन्य', 'अप्रयोजक', 'असमान'] False
# जोडीचा 51 ['अन्य', 'आनुषंगिक'] False
# विचक्षणा 59 ['अन्वेषण', 'अभिरुची'] False
# पूसतपास 101 ['अन्वेषण', 'आदर'] False
# पाहणी 61 ['अन्वेषण', 'अवलोकन'] False
# परीक्षण 72 ['अन्वेषण', 'अवलोकन', 'आढावा'] False
# अप्रतिष्ठा 53 ['अपकीर्ती', 'अपमान'] False
# बदनामी 47 ['अपकीर्ती', 'अपभाषण'] False
# मानहानी 53 ['अपकीर्ती', 'अपमान'] False
# मानखंडना 53 ['अपकीर्ती', 'अपमान'] False
# नाचक्की 53 ['अपकीर्ती', 'अपमान'] False
# बेअब्रू 53 ['अपकीर्ती', 'अपमान'] False
# काळोखी 34 ['अपकीर्ती', 'अभ्र'] False
# लोकापवाद 41 ['अपकीर्ती', 'अफवा'] False
# पोटशूळ 39 ['अपचन', 'असूया'] False
# पोटदुखी 39 ['अपचन', 'असूया'] False
# निंदानालस्ती 58 ['अपभाषण', 'अपमान'] False
# अवहेलना 58 ['अपभाषण', 'अपमान'] False
# विकृती 36 ['अपभ्रंश', 'आजार'] False
# विकार 36 ['अपभ्रंश', 'आजार'] False
# विचलन 31 ['अपभ्रंश', 'आडमार्ग'] False
# अधिक्षेप 55 ['अपमान', 'आगळीक', 'आज्ञाभंग'] False
# दोषार्ह 20 ['निषिद्ध', 'अर्वाच्य'] False
# अपराध 45 ['अपराध', 'अवगुण', 'आगळीक'] False
# दोष 62 ['अपराध', 'अवगुण', 'आजार'] False
# आगळीक 26 ['अपराध', 'आगळीक'] False
# कसूर 58 ['अपराध', 'अभाव'] False
# प्रमाद 32 ['अपराध', 'अविचार'] False
# सत्यापलाप 25 ['अपलाप', 'असत्य'] False
# खोटेपणा 25 ['अपलाप', 'असत्य'] False
# विपर्यास 25 ['अपलाप', 'असत्य'] False
# ठपका 20 ['अपवाद', 'आक्षेप'] False
# exception 20 ['अपवाद', 'आक्षेप'] False
# अभद्र 84 ['अपवित्र', 'अपशकुनी', 'अभद्र', 'अशिष्ट', 'अशुभ'] False
# ओंगळ 49 ['अपवित्र', 'अभद्र', 'अशुभ'] False
# बीभत्स 57 ['अपवित्र', 'अभद्र', 'असंस्कृत'] False
# दुर्लक्षण 25 ['अपशकुन', 'अवगुण'] False
# कुलक्षण 25 ['अपशकुन', 'अवगुण'] False
# अपशकुनी 37 ['अपशकुनी', 'अभद्र', 'अशुभ'] False
# अनिष्टसूचक 37 ['अपशकुनी', 'अभद्र', 'अशुभ'] False
# ominous 22 ['अपशकुनी', 'अशुभ'] False
# पीडा 44 ['अपाय', 'आजार'] False
# बाधा 44 ['अपाय', 'आजार'] False
# उपद्रव 44 ['अपाय', 'आजार'] False
# बिघाड 44 ['अपाय', 'आजार'] False
# नवलाई 47 ['अपूर्वाई', 'आश्चर्य'] False
# कौतुक 54 ['अपूर्वाई', 'अभिनंदन', 'आश्चर्य'] False
# इच्छा 185 ['अपेक्षा', 'अभिलाषा', 'आकांक्षा', 'आशा', 'आसक्ती', 'इच्छा'] False
# आकांक्षा 145 ['अपेक्षा', 'आकांक्षा', 'आशा', 'इच्छा'] False
# कांक्षा 137 ['अपेक्षा', 'अभिलाषा', 'आकांक्षा', 'इच्छा'] False
# वांछा 98 ['अपेक्षा', 'इच्छा'] False
# आशा 145 ['अपेक्षा', 'आकांक्षा', 'आशा', 'इच्छा'] False
# उमेद 73 ['अपेक्षा', 'आकांक्षा', 'आशा', 'आश्वासन'] False
# मागणी 129 ['अपेक्षा', 'अभ्यर्थना', 'इच्छा'] False
# expectation 35 ['अपेक्षा', 'आशा'] False
# desire 64 ['अपेक्षा', 'अभिलाषा', 'असोशी', 'आकांक्षा'] False
# अप्रचलित 18 ['अप्रचलित', 'अप्रसिद्ध'] False
# vulgar 40 ['अप्रशस्त', 'अशिष्ट'] False
# अप्रसन्न 29 ['अप्रसन्न', 'असंतुष्ट'] False
# नाराज 29 ['अप्रसन्न', 'असंतुष्ट'] False
# नाखूश 29 ['अप्रसन्न', 'असंतुष्ट'] False
# रुष्ट 29 ['अप्रसन्न', 'असंतुष्ट'] False
# इतराजी 69 ['अप्रसन्न', 'अप्रीती', 'अवकृपा', 'असंतोष'] False
# गैरमर्जी 26 ['अप्रसन्न', 'अवकृपा'] False
# नापसंत 25 ['अप्रिय', 'असंमत'] False
# तापदायक 33 ['अप्रिय', 'असह्य'] False
# असंतोष 111 ['अप्रीती', 'अवकृपा', 'अशांतता', 'असंतोष'] False
# नाराजी 57 ['अप्रीती', 'अवकृपा', 'असंतोष'] False
# अवकृपा 57 ['अप्रीती', 'अवकृपा', 'असंतोष'] False
# द्वेष 44 ['अप्रीती', 'असूया'] False
# चीड 43 ['अप्रीती', 'असंतोष'] False
# गप्प 58 ['अफवा', 'अबोल'] False
# बोंब 63 ['अफवा', 'अभाव'] False
# अविरोध 18 ['अबाधित', 'अविरोध'] False
# वादातीत 27 ['अबाधित', 'असंदिग्ध'] False
# निर्विवाद 27 ['अबाधित', 'असंदिग्ध'] False
# unopposed 18 ['अबाधित', 'अविरोध'] False
# मौन 48 ['अबोल', 'अबोला'] False
# चिप्प 87 ['अबोल', 'आर्द्र'] False
# मुग्ध 62 ['अबोल', 'अस्पष्ट'] False
# मानमान्यता 81 ['अब्रू', 'आदर'] False
# नाव 41 ['अब्रू', 'अभिधान'] False
# दबदबा 81 ['अब्रू', 'आदर'] False
# sinister 29 ['अभद्र', 'अशुभ'] False
# पोकळी 67 ['अभाव', 'अवकाश'] False
# उणेपणा 62 ['अभाव', 'अवगुण'] False
# अभिजन 79 ['अभिजन', 'आप्त'] False
# प्रतिष्ठित 22 ['अभिजन', 'असामी'] False
# सन्मान्य 22 ['अभिजन', 'असामी'] False
# स्तुती 18 ['अभिनंदन', 'आभार'] False
# आनंदप्रदर्शन 61 ['अभिनंदन', 'आनंद'] False
# आविर्भाव 52 ['अभिनय', 'आव', 'आविर्भाव'] False
# हावभाव 38 ['अभिनय', 'आविर्भाव'] False
# मुद्रा 38 ['अभिनय', 'आविर्भाव'] False
# अंगविक्षेप 38 ['अभिनय', 'आविर्भाव'] False
# हातवारे 38 ['अभिनय', 'आविर्भाव'] False
# अवतार 62 ['अभिनय', 'अवतार', 'आव', 'आविर्भाव'] False
# acting 38 ['अभिनय', 'आविर्भाव'] False
# अभिनिवेश 62 ['अभिनिवेश', 'आग्रह', 'आत्मविश्वास'] False
# नेट 59 ['अभिनिवेश', 'अवसान', 'आव'] False
# आवेश 115 ['अभिनिवेश', 'अवसान', 'आव', 'आवेग'] False
# जोम 101 ['अभिनिवेश', 'अवसान', 'आवेग'] False
# जोश 74 ['अभिनिवेश', 'आवेग'] False
# आवेग 128 ['अभिनिवेश', 'अशांतता', 'आवेग'] False
# चेव 128 ['अभिनिवेश', 'अशांतता', 'आवेग'] False
# उत्साह 181 ['अभिनिवेश', 'अवसान', 'आनंद', 'आवेग', 'आश्वासक', 'आश्वासन'] False
# निर्धार 47 ['अभिनिवेश', 'आग्रह'] False
# चैतन्य 143 ['अभिनिवेश', 'अवसान', 'आत्मा', 'आवेग'] False
# जिद्द 62 ['अभिनिवेश', 'आग्रह', 'आत्मविश्वास'] False
# ईर्षा 86 ['अभिनिवेश', 'अभिमान', 'असूया'] False
# तडफ 74 ['अभिनिवेश', 'आवेग'] False
# vigour 45 ['अभिनिवेश', 'अवसान'] False
# अभिन्न 38 ['अभिन्न', 'अविभक्त'] False
# समाईक 38 ['अभिन्न', 'अविभक्त'] False
# अभिप्राय 53 ['अभिप्राय', 'अहवाल'] False
# अर्थ 76 ['अभिप्राय', 'अर्थ'] False
# सार 79 ['अभिप्राय', 'अर्क', 'आराखडा'] False
# सारांश 76 ['अभिप्राय', 'आढावा', 'आराखडा'] False
# उद्देश 118 ['अभिप्राय', 'इच्छा'] False
# मनोगत 118 ['अभिप्राय', 'इच्छा'] False
# मर्म 50 ['अभिप्राय', 'अवगुण'] False
# विचार 38 ['अभिप्राय', 'समालोचन'] False
# मानस 118 ['अभिप्राय', 'इच्छा'] False
# मनसुबा 118 ['अभिप्राय', 'इच्छा'] False
# शेरा 53 ['अभिप्राय', 'अहवाल'] False
# अहवाल 64 ['अभिप्राय', 'अहवाल', 'आढावा'] False
# अहंता 56 ['अभिमान', 'अस्मिता', 'अहं'] False
# अहंभाव 43 ['अभिमान', 'अहं'] False
# अहंकार 43 ['अभिमान', 'अहं'] False
# अहंपणा 43 ['अभिमान', 'अहं'] False
# ताठा 76 ['अभिमान', 'अभिमान'] True
# तोरा 58 ['अभिमान', 'अवडंबर'] False
# ऐट 58 ['अभिमान', 'अवडंबर'] False
# आत्मसंतुष्टता 92 ['अभिमान', 'आनंद'] False
# तेजस्विता 51 ['अभिमान', 'अस्मिता'] False
# गर्विष्ठ 56 ['अभिमान', 'अरेराव'] False
# अस्मिता 51 ['अभिमान', 'अस्मिता'] False
# स्वाभिमान 20 ['स्वाभिमान', 'अस्मिता'] False
# अभिलाषा 127 ['अभिलाषा', 'आसक्ती', 'इच्छा'] False
# लालसा 141 ['अभिलाषा', 'असोशी', 'आसक्ती', 'इच्छा'] False
# तृष्णा 141 ['अभिलाषा', 'असोशी', 'आसक्ती', 'इच्छा'] False
# वासना 150 ['अभिलाषा', 'आकांक्षा', 'आसक्ती', 'इच्छा'] False
# कामना 103 ['अभिलाषा', 'इच्छा'] False
# कामातुरता 40 ['अभिलाषा', 'आसक्ती'] False
# हाव 63 ['अभिलाषा', 'आकांक्षा', 'आसक्ती'] False
# avarice 40 ['अभिलाषा', 'आसक्ती'] False
# अभिवंदन 31 ['अभिवंदन', 'अभीष्टचिंतन'] False
# नमन 153 ['अभिवंदन', 'अभ्यर्थना', 'आरंभ', 'आराधना'] False
# अभ्युत्थान 102 ['अभिवंदन', 'अभ्युदय', 'आदर'] False
# मानवंदना 85 ['अभिवंदन', 'आदर'] False
# सलामी 167 ['अभिवंदन', 'आदर', 'आरंभ'] False
# सत्कार 85 ['अभिवंदन', 'आदर'] False
# अभिव्यक्ती 44 ['अभिव्यक्ती', 'आविर्भाव'] False
# आविष्करण 45 ['अभिव्यक्ती', 'आविष्करण'] False
# आविष्कार 61 ['अभिव्यक्ती', 'आविर्भाव', 'आविष्करण'] False
# प्रकटन 45 ['अभिव्यक्ती', 'आविष्करण'] False
# प्रदर्शन 93 ['अभिव्यक्ती', 'अवडंबर', 'आरास', 'आविष्करण'] False
# दर्शन 50 ['अभिव्यक्ती', 'अवलोकन'] False
# मांडणी 103 ['अभिव्यक्ती', 'अवस्था', 'आखणी', 'आराखडा'] False
# निवेदन 59 ['अभिव्यक्ती', 'अभ्यर्थना'] False
# आलेखन 42 ['अभिव्यक्ती', 'आखणी'] False
# expression 45 ['अभिव्यक्ती', 'आविष्करण'] False
# अभीष्टचिंतन 26 ['अभीष्टचिंतन', 'आशीर्वचन'] False
# शुभचिंतन 26 ['अभीष्टचिंतन', 'आशीर्वचन'] False
# शुभेच्छा 95 ['अभीष्टचिंतन', 'इच्छा'] False
# सदिच्छा 95 ['अभीष्टचिंतन', 'इच्छा'] False
# आशीर्वाद 26 ['अभीष्टचिंतन', 'आशीर्वचन'] False
# अभ्यर्थना 39 ['अभ्यर्थना', 'मनधरणी'] False
# आळवणी 48 ['अभ्यर्थना', 'आराधना'] False
# विनंती 60 ['अभ्यर्थना', 'आग्रह'] False
# मिनतवारी 39 ['अभ्यर्थना', 'मनधरणी'] False
# याचना 56 ['अभ्यर्थना', 'आराधना', 'मनधरणी'] False
# request 48 ['अभ्यर्थना', 'आराधना'] False
# अभ्युदय 99 ['अभ्युदय', 'आरंभ'] False
# उदय 99 ['अभ्युदय', 'आरंभ'] False
# अक्षय्य 40 ['अमर', 'अवीट'] False
# अक्षर 85 ['अमर', 'अक्षर', 'आत्मा'] False
# चिरंजीव 39 ['अमर', 'आयुष्मान'] False
# चिरायू 39 ['अमर', 'आयुष्मान'] False
# अवीट 40 ['अमर', 'अवीट'] False
# अमुक 24 ['अमुक', 'अलताभलता'] False
# अमूर्त 27 ['अमूर्त', 'अव्यक्त'] False
# अव्यक्त 51 ['अमूर्त', 'अव्यक्त', 'अस्पष्ट'] False
# तीक्ष्ण 35 ['अमोघ', 'असह्य'] False
# आडरान 53 ['अरण्य', 'आडमार्ग'] False
# आडदांड 28 ['अरबट', 'अरेराव'] False
# uncivilised 32 ['अरबट', 'असंस्कृत'] False
# पचपचीत 60 ['अरसिक', 'आर्द्र'] False
# घोटाळ्याचे 35 ['अरळ', 'अव्यवस्थित'] False
# अराजक 102 ['अराजक', 'अशांतता', 'अस्थैर्य'] False
# अशांतता 131 ['अराजक', 'अशांतता', 'असंतोष', 'अस्थैर्य'] False
# चळवळ 131 ['अराजक', 'अशांतता', 'असंतोष', 'अस्थैर्य'] False
# अस्थैर्य 200 ['अराजक', 'अशांतता', 'अशांतता', 'असंतोष', 'अस्थिर', 'अस्थैर्य'] True
# विस्कळीत 55 ['अराजक', 'अव्यवस्थित'] False
# चढाईखोर 28 ['अरेराव', 'आक्रमक'] False
# भांडखोर 28 ['अरेराव', 'आक्रमक'] False
# सत्त्व 69 ['अर्क', 'अस्मिता', 'आत्मा'] False
# धनदौलत 90 ['अर्थ', 'अर्थ'] True
# बचत 38 ['रोखा', 'अवशिष्ट'] False
# बळी 23 ['अर्पिणे', 'आहुती'] False
# sacrifice 23 ['अर्पिणे', 'आहुती'] False
# चटोर 43 ['अर्वाच्य', 'अशिष्ट'] False
# चहाटळ 33 ['अर्वाच्य', 'आचरट'] False
# बाष्कळ 33 ['अर्वाच्य', 'आचरट'] False
# वात्रट 33 ['अर्वाच्य', 'आचरट'] False
# शोभा 84 ['अलंकार', 'अवडंबर', 'आभा', 'आरास'] False
# शृंगार 47 ['अलंकार', 'आरास'] False
# रंगेल 81 ['अलबेला', 'आनंदित'] False
# विलासी 81 ['अलबेला', 'आनंदित'] False
# निर्मळ 26 ['अलिप्त', 'अव्यंग'] False
# विराम 47 ['अवकाश', 'आराम'] False
# सवड 38 ['अवकाश', 'अवधी'] False
# फुरसत 61 ['अवकाश', 'अवधी', 'आराम'] False
# वेळ 38 ['अवकाश', 'अवधी'] False
# उशीर 62 ['अवकाश', 'अवधी', 'अळंटळं'] False
# काळ 65 ['अवकाश', 'अवधी', 'अवस्था'] False
# समय 38 ['अवकाश', 'अवधी'] False
# अवसर 38 ['अवकाश', 'अवधी'] False
# अप्रसन्नता 43 ['अवकृपा', 'असंतोष'] False
# राग 43 ['अवकृपा', 'असंतोष'] False
# गुंडाळणे 57 ['अवगुंठन', 'आटोपणे'] False
# ठोक 136 ['अवघा', 'आघात'] False
# गुरू 38 ['अवजड', 'आचार्य'] False
# डामडौल 63 ['अवडंबर', 'आरास', 'इतमाम'] False
# थाटमाट 48 ['अवडंबर', 'आरास'] False
# भपका 48 ['अवडंबर', 'आरास'] False
# देखावा 69 ['अवडंबर', 'आभास', 'आरास'] False
# दिमाख 35 ['अवडंबर', 'इतमाम'] False
# आव 103 ['अवडंबर', 'अवसान', 'आकार', 'आव', 'आविर्भाव'] False
# pomp 48 ['अवडंबर', 'आरास'] False
# show 34 ['अवडंबर', 'आव'] False
# मूर्ती 36 ['अवतार', 'आकार'] False
# स्वरूप 105 ['अवतार', 'अवस्था', 'आकार', 'आत्मा'] False
# चित्त 55 ['अवधान', 'आत्मा'] False
# उसंत 37 ['अवधी', 'आराम'] False
# भरवसा 33 ['अवलंबन', 'अवलंबन', 'आश्वासन'] True
# विश्वास 56 ['अवलंबन', 'आशा', 'आस्था'] False
# कटाक्ष 30 ['कटाक्ष', 'कटाक्ष'] True
# समालोचन 18 ['समालोचन', 'आढावा'] False
# सिंहावलोकन 18 ['समालोचन', 'आढावा'] False
# अवशेष 28 ['अवशिष्ट', 'अवशेष'] False
# तेज 44 ['अवसान', 'आभा'] False
# जोर 83 ['अवसान', 'आवेग'] False
# शक्ती 53 ['अवसान', 'आवाका'] False
# निग्रह 71 ['अवसान', 'आग्रह', 'आत्मविश्वास'] False
# दम 69 ['अवसान', 'आवाका', 'आव्हान'] False
# त्वेष 83 ['अवसान', 'आवेग'] False
# धीर 68 ['अवसान', 'आत्मविश्वास', 'आश्वासक', 'आश्वासन'] False
# मनोधैर्य 42 ['अवसान', 'आत्मविश्वास'] False
# धमक 42 ['अवसान', 'आत्मविश्वास'] False
# उभारी 42 ['अवसान', 'आत्मविश्वास'] False
# जीव 102 ['अवसान', 'आत्मा', 'आयुष्य'] False
# प्राण 107 ['अवसान', 'नांदणूक', 'आत्मा', 'आयुष्य'] False
# घडण 101 ['अवस्था', 'आकार', 'आराखडा', 'आव'] False
# रचना 61 ['अवस्था', 'आराखडा'] False
# रासभ्य 42 ['अविचार', 'अज्ञान'] False
# उतावळेपणा 71 ['अविचार', 'अशांतता'] False
# उल्लू 37 ['अविचारी', 'आचरट'] False
# हास्यास्पद 37 ['अविचारी', 'आचरट'] False
# तट्कन 166 ['अविलंब', 'अविलंब'] True
# perfect 36 ['अव्यंग', 'आदर्श'] False
# बकाल 46 ['अव्यवस्थित', 'असंस्कृत'] False
# काल्पनिक 55 ['अशक्य', 'आश्चर्य'] False
# चेकाळणे 94 ['अशांत', 'आवेग'] False
# थरकणे 51 ['अशांत', 'फडफडणे'] False
# अस्वस्थता 83 ['अशांतता', 'असंतोष'] False
# अस्वास्थ्य 82 ['अशांतता', 'आजार'] False
# बेचैनी 83 ['अशांतता', 'असंतोष'] False
# क्षोभ 110 ['अशांतता', 'आवेग'] False
# प्रक्षोभ 110 ['अशांतता', 'आवेग'] False
# उत्कंठा 124 ['अशांतता', 'आकांक्षा', 'आशा', 'आस्था'] False
# चंचलता 71 ['अशांतता', 'अस्थैर्य'] False
# उसळी 110 ['अशांतता', 'आवेग'] False
# लोकक्षोभ 83 ['अशांतता', 'असंतोष'] False
# ferment 100 ['अशांतता', 'असंतोष', 'अस्थैर्य'] False
# भलतेसलते 44 ['अशिष्ट', 'आचरट'] False
# असणे 27 ['असणे', 'अस्तित्व'] False
# अतृप्ती 43 ['असंतोष', 'असोशी'] False
# ठसठशीत 78 ['असंदिग्ध', 'आकर्षक'] False
# असोशी 101 ['असोशी', 'इच्छा'] False
# तळमळ 101 ['असोशी', 'इच्छा'] False
# अस्तित्व 43 ['अस्तित्व', 'आयुष्य'] False
# नांदणूक 40 ['नांदणूक', 'आचरण'] False
# जीवन 38 ['नांदणूक', 'आयुष्य'] False
# स्वत्व 55 ['अस्मिता', 'आत्मा'] False
# आत्मा 55 ['अस्मिता', 'आत्मा'] False
# आढावा 33 ['अहवाल', 'आढावा'] False
# टीका 45 ['अहवाल', 'आढावा', 'आक्षेप'] False
# टाचण 56 ['अहवाल', 'आराखडा'] False
# चालढकल 36 ['अळंटळं', 'आबाळ'] False
# आस 118 ['अक्ष', 'आशा', 'इच्छा'] False
# गंभीर 20 ['अक्षम्य', 'आशयघन'] False
# उमदा 128 ['आकर्षक', 'आनंदित'] False
# भुरळ 77 ['आकर्षण', 'आभास', 'आसक्ती'] False
# मोह 44 ['आकर्षण', 'आमिष'] False
# आकृती 60 ['आकार', 'आराखडा'] False
# ढब 56 ['आकार', 'आव', 'आविर्भाव'] False
# विस्तार 52 ['आकार', 'आवाका'] False
# वांच्छा 134 ['आकांक्षा', 'आशा', 'इच्छा'] False
# स्पृहा 110 ['आकांक्षा', 'इच्छा'] False
# मनीषा 134 ['आकांक्षा', 'आशा', 'इच्छा'] False
# मनोकामना 110 ['आकांक्षा', 'इच्छा'] False
# खुमखुमी 110 ['आकांक्षा', 'इच्छा'] False
# जिगीषा 110 ['आकांक्षा', 'इच्छा'] False
# महत्त्वाकांक्षा 110 ['आकांक्षा', 'इच्छा'] False
# उडी 49 ['आकांक्षा', 'आवाका'] False
# स्वप्न 44 ['आकांक्षा', 'आभास'] False
# हल्ला 124 ['आक्रमण', 'आघात'] False
# वेढा 63 ['आक्रमण', 'आलिंगन'] False
# वेढणे 63 ['आक्रमण', 'आलिंगन'] False
# रूपरेषा 48 ['आखणी', 'आराखडा'] False
# रूपरेखा 48 ['आखणी', 'आराखडा'] False
# साक्षेप 52 ['आग्रह', 'आस्था'] False
# झटका 159 ['आघात', 'आवेग'] False
# ठोसा 206 ['आघात', 'आघात'] True
# झपाटा 159 ['आघात', 'आवेग'] False
# आचका 159 ['आघात', 'आवेग'] False
# आच 41 ['आच', 'आस्था'] False
# काळजी 41 ['आच', 'आस्था'] False
# फिकीर 41 ['आच', 'आस्था'] False
# warmth 40 ['आच', 'आपुलकी'] False
# पंडित 36 ['आचारी', 'आचार्य'] False
# खात्री 30 ['आत्मविश्वास', 'आश्वासन'] False
# दिलासा 30 ['आत्मविश्वास', 'आश्वासन'] False
# स्वकीय 76 ['आत्मीय', 'आप्त'] False
# भक्ती 79 ['आदर', 'आराधना'] False
# श्रद्धा 85 ['आदर', 'आस्था'] False
# निष्ठा 86 ['आदर', 'आसक्ती'] False
# संभावना 124 ['आदर', 'आदर'] True
# मानपान 83 ['आदर', 'आहेर'] False
# मानाचे पान 83 ['आदर', 'आहेर'] False
# आदर्श 29 ['आदर्श', 'आरसा'] False
# कौल 49 ['आदेश', 'आश्वासन'] False
# सुख 131 ['आनंद', 'आनंद', 'आराम'] True
# आराम 77 ['आनंद', 'आराम'] False
# चैन 77 ['आनंद', 'आराम'] False
# स्वास्थ्य 77 ['आनंद', 'आराम'] False
# स्वस्थता 77 ['आनंद', 'आराम'] False
# खुशाली 77 ['आनंद', 'आराम'] False
# कुशल 122 ['आनंद', 'आनंदित'] False
# संबंधी 90 ['आनुषंगिक', 'आप्त'] False
# नातेवाईक 140 ['आप्त', 'आप्त'] True
# घर 105 ['आप्त', 'आलय'] False
# दुवा 29 ['आभार', 'आशीर्वचन'] False
# मनोराज्य 45 ['आभास', 'आशा'] False
# उत्तेजन 27 ['आमिष', 'आश्वासन'] False
# बंदूक 38 ['खड्ग', 'खड्ग'] True
# अस्त्र 35 ['खड्ग', 'आयुध'] False
# जन्म 115 ['आयुष्य', 'आरंभ'] False
# साकांक्ष 43 ['आर्त', 'इच्छुक'] False
# eager 31 ['आर्त', 'आशाळभूत'] False
# सर्द 88 ['आर्द्र', 'आश्चर्य'] False
# निवासस्थान 57 ['आलय', 'आश्रम'] False
# वेग 98 ['आलिंगन', 'आवेग'] False
# भेट 63 ['आलिंगन', 'आहेर'] False
# मिठी मारणे 68 ['आलिंगन', 'आवळणे'] False
# आवळणे 68 ['आलिंगन', 'आवळणे'] False
# पवित्रा 30 ['आव', 'आविर्भाव'] False
# सळ 112 ['आवेग', 'आवेग'] True
# ऊर्मी 143 ['आवेग', 'इच्छा'] False
# इच्छुक 42 ['आशाळभूत', 'इच्छुक'] False
# आश्वासन 26 ['आश्वासक', 'आश्वासन'] False
# स्वारस्य 111 ['आसक्ती', 'इच्छा'] False
# मुमूर्षू 56 ['आसन्नमरण', 'इच्छुक'] False

# %%
newdict = dict()
for k in mydict.keys():
    mylist = mydict[k]
    mylist.sort(key=len)
    templist = list()
    templist.append(mylist[0])
    for i in mylist[1:]:
        if i[0] == k:
            pass
        else:
            i.remove(k)
        templist.append(i)
    newdict[k] = templist

# %%
finaldict = defaultdict(list)
for k in newdict.keys():
    mylist = newdict[k]
    for i in mylist:
        finaldict[i[0]].append(set(i[1:]))

# %%
fdict = dict()
for k in finaldict.keys():
    fdict[k] = set.intersection(*finaldict[k])

# %%
myobj = open("/tmp/newfile.txt", "w")

# %%
mysys = sys.stdout
sys.stdout = myobj

# %%
for k in fdict.keys():
    print(k + ",", ", ".join(fdict[k]))

# %%
lfile = open("/tmp/lfile.txt", "w")

# %%
sys.stdout = lfile

# %%
# !sed -i '/^$/d' /tmp/newfile.txt

# %%
with open("/tmp/newfile.txt", "r") as n:
    finlist = dict()
    for nline in n:
        finlist[nline.split()[0]] = nline.split()[1:]

# %%
with open(input_file, "r") as f:
    for fline in f:
        if fline.split()[0] in finlist:
            print(fline.split()[0], " ".join(finlist[fline.split()[0]]))
        else:
            print(fline)

# %%
# !cat /tmp/lfile.txt | sed 's/\‚/,/g' | sed '/^$/d' | sed 's/\ \,/\,/g' | sed 's/\ \ /\ /g' | sed '/\,$/d' | sed '/\,\ $/d' > /tmp/lfile3.txt
