# %%
import sys
from collections import Counter, defaultdict

# %%
# !dos2unix /tmp/f2.txt
# Out:
# dos2unix: converting file /tmp/f2.txt to Unix format...

# %%
#!apt-get install --yes dos2unix

# %%
# !cat /tmp/f2.txt | sed 's/\‚/,/g' | sed '/^$/d' | sed 's/\ \,/\,/g' | sed 's/\ \ /\ /g' | sed '/\,$/d' | sed '/\,\ $/d' > /tmp/f3.txt

# %%
input_file = '/tmp/f3.txt'
lines = open(input_file).read().splitlines()

# %%
outerlist = list()
for i in lines:
    mylist = list()
    for x in i.split(","):
        mylist.append(x.strip())
    outerlist.append(mylist)

# %%
theList = [x for x in outerlist if x != [""]]
for i in range(len(theList)):
    theList[i] = list(filter(None, theList[i]))

# %%
mylist = list()
for i in theList:
    for x in i:
        mylist.append(x)

# %%
c = Counter(mylist)
[el for el in c.items() if el[1] > 1]
# Out:
# [('अकटोविकट', 2),
#  ('प्रचंड', 4),
#  ('अचाट', 4),
#  ('अफाट', 4),
#  ('विशाल', 2),
#  ('भव्य', 2),
#  ('अकरणीय', 2),
#  ('त्याज्य', 2),
#  ('अयोग्य', 2),
#  ('द्वाड', 2),
#  ('निष्ठुर', 2),
#  ('निर्दय', 3),
#  ('क्रूर', 2),
#  ('अकल्पित', 2),
#  ('अनपेक्षित', 2),
#  ('आगंतुक', 2),
#  ('अकस्मात', 2),
#  ('अनिष्ट', 2),
#  ('योगायोग', 2),
#  ('व्यर्थ', 2),
#  ('अंकुश', 2),
#  ('ताबा', 2),
#  ('हुकमत', 3),
#  ('नियंत्रण', 4),
#  ('निर्बंध', 4),
#  ('मर्यादा', 2),
#  ('शुद्ध', 2),
#  ('अस्सल', 2),
#  ('खरा', 2),
#  ('अल्लड', 2),
#  ('आपत्ती', 2),
#  ('अभेद्य', 2),
#  ('एक', 2),
#  ('अतूट', 2),
#  ('अविरत', 2),
#  ('निरंतर', 2),
#  ('अव्याहत', 2),
#  ('कायम', 2),
#  ('नित्य', 2),
#  ('अखेर', 2),
#  ('शेवट', 3),
#  ('अंत', 3),
#  ('समाप्ती', 2),
#  ('परिसमाप्ती', 2),
#  ('सांगता', 2),
#  ('पूर्णविराम', 2),
#  ('अस्त', 2),
#  ('लय', 2),
#  ('विलय', 2),
#  ('विसर्जन', 2),
#  ('बरखास्ती', 2),
#  ('बोळवण', 2),
#  ('नाश', 2),
#  ('टोक', 2),
#  ('कड', 2),
#  ('सीमा', 3),
#  ('परिसीमा', 3),
#  ('हद्द', 3),
#  ('कळस', 4),
#  ('उपसंहार', 2),
#  ('क्षमता', 2),
#  ('फड', 3),
#  ('निराधार', 2),
#  ('आस्था', 2),
#  ('कळकळ', 2),
#  ('अतर्क्य', 3),
#  ('अगाध', 2),
#  ('कल्पनातीत', 3),
#  ('गहन', 2),
#  ('अमर्याद', 4),
#  ('स्वीकृती', 2),
#  ('संमती', 3),
#  ('अनुमती', 3),
#  ('मान्यता', 3),
#  ('रुकार', 3),
#  ('मंजुरी', 2),
#  ('कबुली', 2),
#  ('होम', 2),
#  ('चिता', 2),
#  ('भट्टी', 2),
#  ('दहन', 2),
#  ('दाह', 2),
#  ('भाजणे', 2),
#  ('अणकुची', 2),
#  ('शिखर', 2),
#  ('श्रेष्ठ', 2),
#  ('सर्वश्रेष्ठ', 2),
#  ('परम', 2),
#  ('लोकोत्तर', 3),
#  ('निपुण', 2),
#  ('विलक्षण', 3),
#  ('चमत्कारिक', 2),
#  ('चमत्कृतिपूर्ण', 2),
#  ('विचित्र', 2),
#  ('अद्भुत', 3),
#  ('अभूतपूर्व', 2),
#  ('अजब', 2),
#  ('आश्चर्यकारक', 2),
#  ('दुष्ट', 4),
#  ('सैतानी', 2),
#  ('पाशवी', 2),
#  ('अमानुष', 2),
#  ('रानटी', 2),
#  ('निंद्य', 2),
#  ('गर्हणीय', 2),
#  ('अतिरेकी', 3),
#  ('पक्का', 2),
#  ('निश्चेष्ट', 2),
#  ('अलौकिक', 3),
#  ('अपूर्व', 2),
#  ('असामान्य', 3),
#  ('बेसुमार', 2),
#  ('अतिशय', 2),
#  ('तंतोतंत', 2),
#  ('विश्वसनीय', 2),
#  ('अमोघ', 2),
#  ('जड', 2),
#  ('शंका', 3),
#  ('अकुशल', 2),
#  ('अडाणी', 2),
#  ('व्यवहारशून्य', 2),
#  ('अप्रबुद्ध', 2),
#  ('बुद्धिमंद', 2),
#  ('मूर्ख', 2),
#  ('बैलोबा', 2),
#  ('अनन्यसाधारण', 2),
#  ('अट', 2),
#  ('बंध', 2),
#  ('नियम', 2),
#  ('अटक', 2),
#  ('अडथळा', 3),
#  ('अडसर', 2),
#  ('अडचण', 3),
#  ('व्यत्यय', 3),
#  ('विघ्न', 2),
#  ('विक्षेप', 2),
#  ('खंड', 2),
#  ('संकट', 2),
#  ('कोंडी', 2),
#  ('अंतराय', 2),
#  ('प्रतिबंध', 2),
#  ('विरोध', 2),
#  ('भाग', 2),
#  ('अडणे', 2),
#  ('तळ', 2),
#  ('स्थान', 3),
#  ('न्यूनाधिक्य', 2),
#  ('मधला', 2),
#  ('शिरकाव', 2),
#  ('अतिरेक', 2),
#  ('अमाप', 2),
#  ('अवाजवी', 2),
#  ('वारेमाप', 2),
#  ('विपुल', 2),
#  ('पुष्कळ', 2),
#  ('फार', 2),
#  ('खूप', 2),
#  ('चिकार', 2),
#  ('मुबलक', 2),
#  ('उदंड', 3),
#  ('अतृप्त', 2),
#  ('हावरट', 2),
#  ('अधाशी', 2),
#  ('लोभी', 2),
#  ('शागीर्द', 2),
#  ('अनुयायी', 2),
#  ('मदतनीस', 2),
#  ('आर्जव', 2),
#  ('शासन', 2),
#  ('सख्य', 2),
#  ('एकवाक्यता', 2),
#  ('अंध', 2),
#  ('आसक्त', 2),
#  ('अधिष्ठान', 2),
#  ('प्रभुत्व', 2),
#  ('हुकूम', 2),
#  ('अधीक्षक', 2),
#  ('बैठक', 2),
#  ('कृपा', 2),
#  ('जुळणारा', 2),
#  ('उचित', 2),
#  ('इष्ट', 2),
#  ('अनुकूलता', 2),
#  ('आराधना', 2),
#  ('प्रार्थना', 2),
#  ('अनुबंध', 2),
#  ('आकर्षण', 2),
#  ('अनुसंधान', 2)]

# %%
mydict = defaultdict(list)
for el in c.items():
    if el[1] > 1:
        for i in theList:
            for x in i:
                if x == el[0]:
                    mydict[x].append(i)

# %%
mydict["अचाट"]
# Out:
# [['अकटोविकट',
#   'अवाढव्य',
#   'अक्राळविक्राळ',
#   'अजस्त्र',
#   'पर्वतप्राय',
#   'भीमकाय',
#   'अगडबंब',
#   'प्रचंड',
#   'अचाट',
#   'अफाट',
#   'जंगी',
#   'विशाल',
#   'विराट',
#   'जगड्व्याळ',
#   'भव्य',
#   'बेढब',
#   'आडमाप',
#   'धिप्पाड',
#   'लठ्ठ',
#   'अवजड',
#   'बोजड'],
#  ['अचाट',
#   'विलक्षण',
#   'अलौकिक',
#   'अद्भुत',
#   'अमानवी',
#   'अतिमानवी',
#   'अपूर्व',
#   'असामान्य',
#   'अफलातून',
#   'कल्पनातीत',
#   'अतर्क्य',
#   'प्रचंड',
#   'अफाट',
#   'बेफाट',
#   'अकटोविकट',
#   'अमर्याद',
#   'बेसुमार',
#   'विशाल',
#   'पराकोटीचा',
#   'भव्य',
#   'श्रेष्ठ',
#   'अतिशय'],
#  ['अतिशय',
#   'अतीव',
#   'अतोनात',
#   'अत्यंत',
#   'अमर्याद',
#   'असीम',
#   'निस्सीम',
#   'अपार',
#   'अपरिमित',
#   'अमित',
#   'अमाप',
#   'अमूप',
#   'अलोट',
#   'अपरंपार',
#   'नितांत',
#   'निरतिशय',
#   'परम',
#   'अवर्णनीय',
#   'आत्यंतिक',
#   'आटोकाट',
#   'बेसुमार',
#   'प्रमाणाबाहेर',
#   'भरमसाट',
#   'अवास्तव',
#   'अवाजवी',
#   'वारेमाप',
#   'अचाट',
#   'अफाट',
#   'बेहद्द',
#   'बेफाम',
#   'जबरदस्त',
#   'अनिवार',
#   'कल्पनातीत',
#   'विपुल',
#   'पुष्कळ',
#   'फार',
#   'भरपूर',
#   'खूप',
#   'चिकार',
#   'गडगंज',
#   'भरघोस',
#   'भरभरून',
#   'मुबलक',
#   'महामूर',
#   'पुरेपूर',
#   'उदंड',
#   'घसघशीत',
#   'तडाखेबंद',
#   'प्रचंड',
#   'तुफान',
#   'कमालीचा',
#   'उदंड'],
#  ['अद्भुत',
#   'विलक्षण',
#   'अजब',
#   'आश्चर्यकारक',
#   'विस्मयजनक',
#   'विचित्र',
#   'चमत्कारिक',
#   'चमत्कृतिपूर्ण',
#   'नवलाईचा',
#   'और',
#   'अनोखा',
#   'अलौकिक',
#   'लोकोत्तर',
#   'असामान्य',
#   'असाधारण',
#   'अनन्यसाधारण',
#   'अभूतपूर्व',
#   'अपूर्व',
#   'अचाट',
#   'दुर्मीळ',
#   'चाकोरीबाहेरचा',
#   'जादूभरा']]

# %%
for k, v in mydict.items():
    mylen = 0
    myl3 = list()
    for i in v:
        mylen = mylen + len(i)
        myl3.append(i[0])
    print(k, mylen, myl3, len(myl3) > len(set(myl3)))
# Out:
# अकटोविकट 43 ['अकटोविकट', 'अचाट'] False
# प्रचंड 103 ['अकटोविकट', 'अगाध', 'अचाट', 'अतिशय'] False
# अचाट 117 ['अकटोविकट', 'अचाट', 'अतिशय', 'अद्भुत'] False
# अफाट 103 ['अकटोविकट', 'अगाध', 'अचाट', 'अतिशय'] False
# विशाल 43 ['अकटोविकट', 'अचाट'] False
# भव्य 43 ['अकटोविकट', 'अचाट'] False
# अकरणीय 43 ['अकरणीय', 'अनुचित'] False
# त्याज्य 43 ['अकरणीय', 'अनुचित'] False
# अयोग्य 43 ['अकरणीय', 'अनुचित'] False
# द्वाड 27 ['अकरुण', 'अगोचर'] False
# निष्ठुर 24 ['अकरुण', 'अनुदार'] False
# निर्दय 43 ['अकरुण', 'अत्याचार', 'अनुदार'] False
# क्रूर 36 ['अकरुण', 'अघोरी'] False
# अकल्पित 19 ['अकल्पित', 'अकस्मात'] False
# अनपेक्षित 19 ['अकल्पित', 'अकस्मात'] False
# आगंतुक 21 ['अकल्पित', 'अतिथी'] False
# अकस्मात 19 ['अकल्पित', 'अकस्मात'] False
# अनिष्ट 47 ['अकल्याण', 'अनुचित'] False
# योगायोग 30 ['अकस्मात', 'अनुबंध'] False
# व्यर्थ 48 ['अकारण', 'अनुचित'] False
# अंकुश 29 ['अंकुश', 'अणकुची'] False
# ताबा 42 ['अंकुश', 'अधिकार'] False
# हुकमत 58 ['अंकुश', 'अधिकार', 'अनुशासन'] False
# नियंत्रण 119 ['अंकुश', 'अटकाव', 'अधिकार', 'अनुशासन'] False
# निर्बंध 95 ['अंकुश', 'अट', 'अटकाव', 'अनुशासन'] False
# मर्यादा 72 ['अंकुश', 'अटकाव'] False
# शुद्ध 56 ['अकृत्रिम', 'अट्टल'] False
# अस्सल 56 ['अकृत्रिम', 'अट्टल'] False
# खरा 56 ['अकृत्रिम', 'अट्टल'] False
# अल्लड 110 ['अकृत्रिम', 'अजाण'] False
# आपत्ती 72 ['अक्काबाई', 'अटकाव'] False
# अभेद्य 86 ['अखंड', 'अजिंक्य'] False
# एक 105 ['अखंड', 'अजोड'] False
# अतूट 108 ['अखंड', 'अचल'] False
# अविरत 154 ['अखंड', 'अखंड'] True
# निरंतर 154 ['अखंड', 'अखंड'] True
# अव्याहत 154 ['अखंड', 'अखंड'] True
# कायम 108 ['अखंड', 'अचल'] False
# नित्य 108 ['अखंड', 'अचल'] False
# अखेर 86 ['अखेर', 'अंत'] False
# शेवट 105 ['अखेर', 'अग्र', 'अंत'] False
# अंत 133 ['अखेर', 'अखेर', 'अंत'] True
# समाप्ती 86 ['अखेर', 'अंत'] False
# परिसमाप्ती 86 ['अखेर', 'अंत'] False
# सांगता 86 ['अखेर', 'अंत'] False
# पूर्णविराम 86 ['अखेर', 'अंत'] False
# अस्त 86 ['अखेर', 'अंत'] False
# लय 86 ['अखेर', 'अंत'] False
# विलय 86 ['अखेर', 'अंत'] False
# विसर्जन 86 ['अखेर', 'अंत'] False
# बरखास्ती 86 ['अखेर', 'अंत'] False
# बोळवण 86 ['अखेर', 'अंत'] False
# नाश 86 ['अखेर', 'अंत'] False
# टोक 66 ['अखेर', 'अग्र'] False
# कड 86 ['अखेर', 'अंत'] False
# सीमा 108 ['अखेर', 'अंत', 'अतिरेक'] False
# परिसीमा 108 ['अखेर', 'अंत', 'अतिरेक'] False
# हद्द 108 ['अखेर', 'अंत', 'अतिरेक'] False
# कळस 127 ['अखेर', 'अग्र', 'अंत', 'अतिरेक'] False
# उपसंहार 86 ['अखेर', 'अंत'] False
# क्षमता 52 ['अंग', 'अधिकार'] False
# फड 83 ['अंगण', 'अड्डा', 'अड्डा'] True
# निराधार 22 ['अगतिक', 'अधांतरी'] False
# आस्था 49 ['अगत्य', 'अनुकंपा'] False
# कळकळ 49 ['अगत्य', 'अनुकंपा'] False
# अतर्क्य 52 ['अगम्य', 'अघटित', 'अचाट'] False
# अगाध 25 ['अगम्य', 'अगाध'] False
# कल्पनातीत 91 ['अगम्य', 'अचाट', 'अतिशय'] False
# गहन 25 ['अगम्य', 'अगाध'] False
# अमर्याद 89 ['अगाध', 'अचाट', 'अतिशय', 'अतिशयोक्त'] False
# स्वीकृती 41 ['अंगीकार', 'अनुमती'] False
# संमती 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# अनुमती 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# मान्यता 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# रुकार 47 ['अंगीकार', 'अनुकूलता', 'अनुमती'] False
# मंजुरी 41 ['अंगीकार', 'अनुमती'] False
# कबुली 41 ['अंगीकार', 'अनुमती'] False
# होम 110 ['अग्नी', 'अनुष्ठान'] False
# चिता 151 ['अग्नी', 'अंत्येष्टी'] False
# भट्टी 119 ['अग्नी', 'अड्डा'] False
# दहन 151 ['अग्नी', 'अंत्येष्टी'] False
# दाह 172 ['अग्नी', 'अग्नी'] True
# भाजणे 172 ['अग्नी', 'अग्नी'] True
# अणकुची 37 ['अग्र', 'अणकुची'] False
# शिखर 58 ['अग्र', 'अंत'] False
# श्रेष्ठ 50 ['अग्रगण्य', 'अचाट'] False
# सर्वश्रेष्ठ 56 ['अग्रगण्य', 'अजोड'] False
# परम 80 ['अग्रगण्य', 'अतिशय'] False
# लोकोत्तर 78 ['अग्रगण्य', 'अजोड', 'अद्भुत'] False
# निपुण 59 ['अग्रगण्य', 'अट्टल'] False
# विलक्षण 57 ['अघटित', 'अचाट', 'अद्भुत'] False
# चमत्कारिक 35 ['अघटित', 'अद्भुत'] False
# चमत्कृतिपूर्ण 35 ['अघटित', 'अद्भुत'] False
# विचित्र 35 ['अघटित', 'अद्भुत'] False
# अद्भुत 57 ['अघटित', 'अचाट', 'अद्भुत'] False
# अभूतपूर्व 35 ['अघटित', 'अद्भुत'] False
# अजब 35 ['अघटित', 'अद्भुत'] False
# आश्चर्यकारक 35 ['अघटित', 'अद्भुत'] False
# दुष्ट 88 ['अघोरी', 'अत्याचार', 'अधम', 'अनुदार'] False
# सैतानी 57 ['अघोरी', 'अधम'] False
# पाशवी 43 ['अघोरी', 'अत्याचार'] False
# अमानुष 43 ['अघोरी', 'अत्याचार'] False
# रानटी 43 ['अघोरी', 'अत्याचार'] False
# निंद्य 57 ['अघोरी', 'अधम'] False
# गर्हणीय 61 ['अघोरी', 'अनुचित'] False
# अतिरेकी 38 ['अघोरी', 'अतिरेकी', 'अतिशयोक्त'] False
# पक्का 62 ['अचल', 'अट्टल'] False
# निश्चेष्ट 43 ['अचल', 'अचेतन'] False
# अलौकिक 72 ['अचाट', 'अजोड', 'अद्भुत'] False
# अपूर्व 44 ['अचाट', 'अद्भुत'] False
# असामान्य 72 ['अचाट', 'अजोड', 'अद्भुत'] False
# बेसुमार 74 ['अचाट', 'अतिशय'] False
# अतिशय 74 ['अचाट', 'अतिशय'] False
# तंतोतंत 30 ['अचूक', 'अनुकरण'] False
# विश्वसनीय 45 ['अचूक', 'अट्टल'] False
# अमोघ 23 ['अचूक', 'अजिंक्य'] False
# जड 97 ['अचेतन', 'अजाण'] False
# शंका 78 ['अजमास', 'अढी', 'अधोगती'] False
# अकुशल 109 ['अजागळ', 'अजाण'] False
# अडाणी 98 ['अजाण', 'अडमुठा'] False
# व्यवहारशून्य 170 ['अजाण', 'अजाण'] True
# अप्रबुद्ध 91 ['अजाण', 'अदूरदृष्टी'] False
# बुद्धिमंद 106 ['अजाण', 'अधू'] False
# मूर्ख 98 ['अजाण', 'अडमुठा'] False
# बैलोबा 98 ['अजाण', 'अडमुठा'] False
# अनन्यसाधारण 50 ['अजोड', 'अद्भुत'] False
# अट 68 ['अट', 'अटकाव'] False
# बंध 25 ['अट', 'अनुबंध'] False
# नियम 23 ['अट', 'अनुशासन'] False
# अटक 69 ['अटक', 'अटकाव'] False
# अडथळा 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# अडसर 77 ['अटकाव', 'अडगळ'] False
# अडचण 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# व्यत्यय 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# विघ्न 83 ['अटकाव', 'अडचण'] False
# विक्षेप 91 ['अटकाव', 'अंतर'] False
# खंड 91 ['अटकाव', 'अंतर'] False
# संकट 83 ['अटकाव', 'अडचण'] False
# कोंडी 93 ['अटकाव', 'अधोगती'] False
# अंतराय 91 ['अटकाव', 'अंतर'] False
# प्रतिबंध 122 ['अटकाव', 'अटकाव'] True
# विरोध 91 ['अटकाव', 'अंतर'] False
# भाग 14 ['अटळ', 'अंतर्भाव'] False
# अडणे 44 ['अडकणे', 'अडकणे'] True
# तळ 72 ['अड्डा', 'अंत'] False
# स्थान 75 ['अड्डा', 'अधिकार', 'अधिष्ठान'] False
# न्यूनाधिक्य 60 ['अंतर', 'अंतर'] True
# मधला 27 ['अंतरिम', 'अंतर्गत'] False
# शिरकाव 19 ['अंतर्भाव', 'अतिक्रमण'] False
# अतिरेक 41 ['अतिरेक', 'अत्याचार'] False
# अमाप 83 ['अतिशय', 'अनेक'] False
# अवाजवी 59 ['अतिशय', 'अतिशयोक्त'] False
# वारेमाप 60 ['अतिशय', 'अद्वातद्वा'] False
# विपुल 83 ['अतिशय', 'अनेक'] False
# पुष्कळ 83 ['अतिशय', 'अनेक'] False
# फार 63 ['अतिशय', 'अधिक'] False
# खूप 83 ['अतिशय', 'अनेक'] False
# चिकार 83 ['अतिशय', 'अनेक'] False
# मुबलक 83 ['अतिशय', 'अनेक'] False
# उदंड 135 ['अतिशय', 'अतिशय', 'अनेक'] True
# अतृप्त 23 ['अतृप्त', 'अधाशी'] False
# हावरट 23 ['अतृप्त', 'अधाशी'] False
# अधाशी 23 ['अतृप्त', 'अधाशी'] False
# लोभी 23 ['अतृप्त', 'अधाशी'] False
# शागीर्द 33 ['अंतेवासी', 'अनुचर'] False
# अनुयायी 33 ['अंतेवासी', 'अनुचर'] False
# मदतनीस 33 ['अंतेवासी', 'अनुचर'] False
# आर्जव 39 ['अदब', 'अनुनय'] False
# शासन 24 ['अद्दल', 'अनुशासन'] False
# सख्य 42 ['अद्वैत', 'अनुबंध'] False
# एकवाक्यता 30 ['अद्वैत', 'अनुकूलता'] False
# अंध 33 ['अंध', 'अधू'] False
# आसक्त 23 ['अधाशी', 'अनुरक्त'] False
# अधिष्ठान 42 ['अधिकार', 'अधिष्ठान'] False
# प्रभुत्व 47 ['अधिकार', 'अनुशासन'] False
# हुकूम 47 ['अधिकार', 'अनुशासन'] False
# अधीक्षक 21 ['अधिकारी', 'अधीक्षक'] False
# बैठक 20 ['अधिवेशन', 'अधिष्ठान'] False
# कृपा 36 ['अनुकंपा', 'अनुग्रह'] False
# जुळणारा 35 ['अनुकूल', 'अनुरूप'] False
# उचित 35 ['अनुकूल', 'अनुरूप'] False
# इष्ट 35 ['अनुकूल', 'अनुरूप'] False
# अनुकूलता 30 ['अनुकूलता', 'अनुमती'] False
# आराधना 44 ['अनुनय', 'अनुष्ठान'] False
# प्रार्थना 44 ['अनुनय', 'अनुष्ठान'] False
# अनुबंध 30 ['अनुबंध', 'अनुसंधान'] False
# आकर्षण 27 ['अनुबंध', 'अनुरक्ती'] False
# अनुसंधान 30 ['अनुबंध', 'अनुसंधान'] False

# %%
newdict = dict()
for k in mydict.keys():
    mylist = mydict[k]
    mylist.sort(key=len)
    templist = list()
    templist.append(mylist[0])
    for i in mylist[1:]:
        if i[0] == k:
            pass
        else:
            i.remove(k)
        templist.append(i)
    newdict[k] = templist

# %%
finaldict = defaultdict(list)
for k in newdict.keys():
    mylist = newdict[k]
    for i in mylist:
        finaldict[i[0]].append(set(i[1:]))

# %%
fdict = dict()
for k in finaldict.keys():
    fdict[k] = set.intersection(*finaldict[k])

# %%
myobj = open("/tmp/newfile.txt", "w")

# %%
mysys = sys.stdout
sys.stdout = myobj

# %%
for k in fdict.keys():
    print(k + ",", ", ".join(fdict[k]))

# %%
lfile = open("/tmp/lfile.txt", "w")

# %%
sys.stdout = lfile

# %%
# !sed -i '/^$/d' /tmp/newfile.txt

# %%
with open("/tmp/newfile.txt", "r") as n:
    finlist = dict()
    for nline in n:
        finlist[nline.split()[0]] = nline.split()[1:]

# %%
with open(input_file, "r") as f:
    for fline in f:
        if fline.split()[0] in finlist:
            print(fline.split()[0], " ".join(finlist[fline.split()[0]]))
        else:
            print(fline)

# %%
# !cat /tmp/lfile.txt | sed 's/\‚/,/g' | sed '/^$/d' | sed 's/\ \,/\,/g' | sed 's/\ \ /\ /g' | sed '/\,$/d' | sed '/\,\ $/d' > /tmp/lfile3.txt
