# %%
import sys
from collections import Counter, defaultdict

# %%
# !sed -i '/^$/d' /tmp/sw2.txt

# %%
# !head /tmp/sw2.txt
# Out:
# अकटोविकट, अवाढव्य, अक्राळविक्राळ, अजस्त्र, पर्वतप्राय, भीमकाय, अगडबंब, प्रचंड, अचाट, अफाट, जंगी, विशाल, विराट, जगड्व्याळ, भव्य, बेढब, आडमाप, धिप्पाड, लठ्ठ, अवजड, बोजड
# अकरणीय, अविहित, निषिद्ध, त्याज्य, अयोग्य, बेकायदेशीर
# अकरुण, अदय, द्वाड, कृपाहीन, हृदयशून्य, उग्र, कर्कश, कठोर, निष्ठुर, निर्दय, क्रूर, करुणाविहीन
# अकल्पित, अनपेक्षित, आकस्मिक, आगंतुक, अनाहूत, धक्कास्पद, अकस्मात
# अकल्याण, अहित, अनहित, हानी, नुकसान, अपाय, अपकार, अशुभ, अमंगल, अनिष्ट
# अकस्मात, अकल्पित, अचानक, अवचित, एकाएकी, सहसा, अपघात, दैववशात्, कर्मधर्मसंयोग, योगायोग, अनपेक्षित, अभावित
# अकारण, विनाकारण, निष्कारण, निर्निमित्त, निरुद्देश, अहेतुक, व्यर्थ, फुकट, नाहक, निरर्थक, उगाच
# अकाल, अवेळ, कुवेळ, दुर्दिन, कुदिन, कुयोग, घातवार, घातवेळ, अनिष्टग्रह, दुष्काळ, दुकाळ, अवर्षण, अनावृष्टी, दुर्भिक्ष, वाण, चणचण
# अकिंचन, अकांचन, निष्कांचन, निर्धन, द्रव्यहीन, कंगाल, कफल्लक, रंक, खंक, खल्लक, दरिद्री, दळिद्री, जन्मदरिद्री, गरीब, फकीर, नंगा, भिकारडा, भणंग, भिकारी, नष्टैश्वर्य, फटिंग, फाकेकंगाल, भुकेकंगाल, अन्नान्नगत, नादार, दिवाळखोर, अभाव
# अंकित, चिन्हित, भूषित, विभूषित, मानांकित, गौरवांकित, मुद्रांकित , अलंकृत

# %%
lines = open("/tmp/sw2.txt").read().splitlines()

# %%
outerlist = list()
for i in lines:
    mylist = list()
    for x in i.split(","):
        mylist.append(x.strip())
    outerlist.append(mylist)

# %%
theList = [x for x in outerlist if x != [""]]
for i in range(len(theList)):
    theList[i] = list(filter(None, theList[i]))

# %%
mylist = list()
for i in theList:
    for x in i:
        mylist.append(x)

# %%
c = Counter(mylist)
[el for el in c.items() if el[1] > 1]
# Out:
# [('अकटोविकट', 2),
#  ('प्रचंड', 4),
#  ('अचाट', 3),
#  ('अफाट', 5),
#  ('विशाल', 2),
#  ('भव्य', 2),
#  ('द्वाड', 2),
#  ('निर्दय', 2),
#  ('क्रूर', 2),
#  ('अकल्पित', 2),
#  ('अनपेक्षित', 2),
#  ('आगंतुक', 2),
#  ('अकस्मात', 2),
#  ('अंकुश', 2),
#  ('ताबा', 2),
#  ('हुकमत', 2),
#  ('नियंत्रण', 3),
#  ('निर्बंध', 3),
#  ('मर्यादा', 2),
#  ('शुद्ध', 3),
#  ('अस्सल', 2),
#  ('खरा', 2),
#  ('निष्पाप', 2),
#  ('निष्कपट', 2),
#  ('अल्लड', 2),
#  ('अवदशा', 2),
#  ('आपत्ती', 2),
#  ('अभेद्य', 2),
#  ('एक', 2),
#  ('अक्षत', 2),
#  ('अतूट', 2),
#  ('अविरत', 2),
#  ('निरंतर', 2),
#  ('अव्याहत', 2),
#  ('शाश्वत', 2),
#  ('कायम', 2),
#  ('अक्षय', 2),
#  ('अनंत', 2),
#  ('नित्य', 2),
#  ('अखेर', 2),
#  ('शेवट', 3),
#  ('अंत', 3),
#  ('समाप्ती', 2),
#  ('परिसमाप्ती', 2),
#  ('सांगता', 2),
#  ('पूर्णविराम', 2),
#  ('अस्त', 2),
#  ('लय', 2),
#  ('विलय', 2),
#  ('विसर्जन', 2),
#  ('बरखास्ती', 2),
#  ('बोळवण', 2),
#  ('नाश', 3),
#  ('टोक', 2),
#  ('कड', 2),
#  ('सीमा', 3),
#  ('परिसीमा', 3),
#  ('हद्द', 3),
#  ('कळस', 4),
#  ('उपसंहार', 2),
#  ('विभाग', 2),
#  ('क्षमता', 2),
#  ('फड', 3),
#  ('निराधार', 2),
#  ('अतर्क्य', 3),
#  ('अगाध', 2),
#  ('कल्पनातीत', 3),
#  ('गहन', 2),
#  ('अमर्याद', 5),
#  ('चिता', 2),
#  ('भट्टी', 2),
#  ('दहन', 2),
#  ('दाह', 2),
#  ('भाजणे', 2),
#  ('अणकुची', 2),
#  ('शिखर', 2),
#  ('अध्वर्यू', 2),
#  ('धुरीण', 2),
#  ('श्रेष्ठ', 2),
#  ('सर्वश्रेष्ठ', 2),
#  ('परम', 2),
#  ('लोकोत्तर', 2),
#  ('निपुण', 2),
#  ('अध्यक्ष', 2),
#  ('विलक्षण', 2),
#  ('अद्भुत', 2),
#  ('दुष्ट', 3),
#  ('सैतानी', 2),
#  ('पाशवी', 2),
#  ('अमानुष', 2),
#  ('रानटी', 2),
#  ('निंद्य', 2),
#  ('अतिरेकी', 3),
#  ('पक्का', 2),
#  ('निश्चेष्ट', 2),
#  ('अलौकिक', 2),
#  ('असामान्य', 2),
#  ('बेसुमार', 2),
#  ('अतिशय', 2),
#  ('निर्दोष', 2),
#  ('विश्वसनीय', 2),
#  ('अमोघ', 2),
#  ('जड', 2),
#  ('शंका', 2),
#  ('अकुशल', 3),
#  ('अजाण', 2),
#  ('अनभ्यस्त', 2),
#  ('अडाणी', 2),
#  ('अननुभवी', 2),
#  ('अपक्व', 2),
#  ('व्यवहारशून्य', 2),
#  ('अशिक्षित', 2),
#  ('बुद्धिमंद', 2),
#  ('मूर्ख', 2),
#  ('बैलोबा', 2),
#  ('अट', 2),
#  ('अटक', 2),
#  ('अडथळा', 3),
#  ('अडसर', 2),
#  ('अडचण', 3),
#  ('व्यत्यय', 3),
#  ('विघ्न', 2),
#  ('विक्षेप', 2),
#  ('खंड', 3),
#  ('संकट', 2),
#  ('अंतराय', 2),
#  ('प्रतिबंध', 2),
#  ('विरोध', 2),
#  ('भाग', 3),
#  ('अडणे', 2),
#  ('तळ', 2),
#  ('स्थान', 3),
#  ('न्यूनाधिक्य', 2),
#  ('मधला', 2),
#  ('शिरकाव', 2),
#  ('अतिरेक', 2),
#  ('असीम', 2),
#  ('अपार', 2),
#  ('अपरिमित', 2),
#  ('अमित', 2),
#  ('अमाप', 2),
#  ('अपरंपार', 2),
#  ('अवाजवी', 2),
#  ('फार', 2),
#  ('उदंड', 2),
#  ('अतृप्त', 2),
#  ('हावरट', 2),
#  ('अधाशी', 2),
#  ('लोभी', 2),
#  ('उमेदवार', 2),
#  ('अधिष्ठान', 2),
#  ('अधिकारी', 2),
#  ('स्वामी', 2),
#  ('धनी', 2),
#  ('मालक', 2),
#  ('अधीक्षक', 3),
#  ('नियामक', 2),
#  ('बैठक', 2),
#  ('पीछेहाट', 2)]

# %%
mydict = defaultdict(list)
for el in c.items():
    if el[1] > 1:
        for i in theList:
            for x in i:
                if x == el[0]:
                    mydict[x].append(i)

# %%
mydict["अचाट"]
# Out:
# [['अकटोविकट',
#   'अवाढव्य',
#   'अक्राळविक्राळ',
#   'अजस्त्र',
#   'पर्वतप्राय',
#   'भीमकाय',
#   'अगडबंब',
#   'प्रचंड',
#   'अचाट',
#   'अफाट',
#   'जंगी',
#   'विशाल',
#   'विराट',
#   'जगड्व्याळ',
#   'भव्य',
#   'बेढब',
#   'आडमाप',
#   'धिप्पाड',
#   'लठ्ठ',
#   'अवजड',
#   'बोजड'],
#  ['अचाट',
#   'विलक्षण',
#   'अलौकिक',
#   'अद्भुत',
#   'अमानवी',
#   'अतिमानवी',
#   'अपूर्व',
#   'असामान्य',
#   'अफलातून',
#   'कल्पनातीत',
#   'अतर्क्य',
#   'प्रचंड',
#   'अफाट',
#   'बेफाट',
#   'अकटोविकट',
#   'अमर्याद',
#   'बेसुमार',
#   'विशाल',
#   'पराकोटीचा',
#   'भव्य',
#   'श्रेष्ठ',
#   'अतिशय'],
#  ['अतिशय',
#   'अतीव',
#   'अतोनात',
#   'अत्यंत',
#   'अमर्याद',
#   'असीम',
#   'निस्सीम',
#   'अपार',
#   'अपरिमित',
#   'अमित',
#   'अमाप',
#   'अमूप',
#   'अलोट',
#   'अपरंपार',
#   'नितांत',
#   'निरतिशय',
#   'परम',
#   'अवर्णनीय',
#   'आत्यंतिक',
#   'आटोकाट',
#   'बेसुमार',
#   'प्रमाणाबाहेर',
#   'भरमसाट',
#   'अवास्तव',
#   'अवाजवी',
#   'वारेमाप',
#   'अचाट',
#   'अफाट',
#   'बेहद्द',
#   'बेफाम',
#   'जबरदस्त',
#   'अनिवार',
#   'कल्पनातीत',
#   'विपुल',
#   'पुष्कळ',
#   'फार',
#   'भरपूर',
#   'खूप',
#   'चिकार',
#   'गडगंज',
#   'भरघोस',
#   'भरभरून',
#   'मुबलक',
#   'महामूर',
#   'पुरेपूर',
#   'उदंड',
#   'घसघशीत',
#   'तडाखेबंद',
#   'प्रचंड',
#   'तुफान',
#   'कमालीचा',
#   'उदंड']]

# %%
for k, v in mydict.items():
    mylen = 0
    myl3 = list()
    for i in v:
        mylen = mylen + len(i)
        myl3.append(i[0])
    print(k, mylen, myl3, len(myl3) > len(set(myl3)))
# Out:
# अकटोविकट 43 ['अकटोविकट', 'अचाट'] False
# प्रचंड 103 ['अकटोविकट', 'अगाध', 'अचाट', 'अतिशय'] False
# अचाट 95 ['अकटोविकट', 'अचाट', 'अतिशय'] False
# अफाट 119 ['अकटोविकट', 'अगाध', 'अचाट', 'अतिशय', 'अनंत'] False
# विशाल 43 ['अकटोविकट', 'अचाट'] False
# भव्य 43 ['अकटोविकट', 'अचाट'] False
# द्वाड 27 ['अकरुण', 'अगोचर'] False
# निर्दय 31 ['अकरुण', 'अत्याचार'] False
# क्रूर 36 ['अकरुण', 'अघोरी'] False
# अकल्पित 19 ['अकल्पित', 'अकस्मात'] False
# अनपेक्षित 19 ['अकल्पित', 'अकस्मात'] False
# आगंतुक 21 ['अकल्पित', 'अतिथी'] False
# अकस्मात 19 ['अकल्पित', 'अकस्मात'] False
# अंकुश 29 ['अंकुश', 'अणकुची'] False
# ताबा 42 ['अंकुश', 'अधिकार'] False
# हुकमत 42 ['अंकुश', 'अधिकार'] False
# नियंत्रण 103 ['अंकुश', 'अटकाव', 'अधिकार'] False
# निर्बंध 79 ['अंकुश', 'अट', 'अटकाव'] False
# मर्यादा 72 ['अंकुश', 'अटकाव'] False
# शुद्ध 73 ['अकृत्रिम', 'अट्टल', 'अनघ'] False
# अस्सल 56 ['अकृत्रिम', 'अट्टल'] False
# खरा 56 ['अकृत्रिम', 'अट्टल'] False
# निष्पाप 42 ['अकृत्रिम', 'अनघ'] False
# निष्कपट 42 ['अकृत्रिम', 'अनघ'] False
# अल्लड 110 ['अकृत्रिम', 'अजाण'] False
# अवदशा 46 ['अक्काबाई', 'अधोगती'] False
# आपत्ती 72 ['अक्काबाई', 'अटकाव'] False
# अभेद्य 86 ['अखंड', 'अजिंक्य'] False
# एक 105 ['अखंड', 'अजोड'] False
# अक्षत 94 ['अखंड', 'अनघ'] False
# अतूट 108 ['अखंड', 'अचल'] False
# अविरत 154 ['अखंड', 'अखंड'] True
# निरंतर 154 ['अखंड', 'अखंड'] True
# अव्याहत 154 ['अखंड', 'अखंड'] True
# शाश्वत 93 ['अखंड', 'अनंत'] False
# कायम 108 ['अखंड', 'अचल'] False
# अक्षय 93 ['अखंड', 'अनंत'] False
# अनंत 93 ['अखंड', 'अनंत'] False
# नित्य 108 ['अखंड', 'अचल'] False
# अखेर 86 ['अखेर', 'अंत'] False
# शेवट 105 ['अखेर', 'अग्र', 'अंत'] False
# अंत 133 ['अखेर', 'अखेर', 'अंत'] True
# समाप्ती 86 ['अखेर', 'अंत'] False
# परिसमाप्ती 86 ['अखेर', 'अंत'] False
# सांगता 86 ['अखेर', 'अंत'] False
# पूर्णविराम 86 ['अखेर', 'अंत'] False
# अस्त 86 ['अखेर', 'अंत'] False
# लय 86 ['अखेर', 'अंत'] False
# विलय 86 ['अखेर', 'अंत'] False
# विसर्जन 86 ['अखेर', 'अंत'] False
# बरखास्ती 86 ['अखेर', 'अंत'] False
# बोळवण 86 ['अखेर', 'अंत'] False
# नाश 121 ['अखेर', 'अंत', 'अधोगती'] False
# टोक 66 ['अखेर', 'अग्र'] False
# कड 86 ['अखेर', 'अंत'] False
# सीमा 108 ['अखेर', 'अंत', 'अतिरेक'] False
# परिसीमा 108 ['अखेर', 'अंत', 'अतिरेक'] False
# हद्द 108 ['अखेर', 'अंत', 'अतिरेक'] False
# कळस 127 ['अखेर', 'अग्र', 'अंत', 'अतिरेक'] False
# उपसंहार 86 ['अखेर', 'अंत'] False
# विभाग 38 ['अंग', 'अध्याय'] False
# क्षमता 52 ['अंग', 'अधिकार'] False
# फड 83 ['अंगण', 'अड्डा', 'अड्डा'] True
# निराधार 22 ['अगतिक', 'अधांतरी'] False
# अतर्क्य 52 ['अगम्य', 'अघटित', 'अचाट'] False
# अगाध 25 ['अगम्य', 'अगाध'] False
# कल्पनातीत 91 ['अगम्य', 'अचाट', 'अतिशय'] False
# गहन 25 ['अगम्य', 'अगाध'] False
# अमर्याद 105 ['अगाध', 'अचाट', 'अतिशय', 'अतिशयोक्त', 'अनंत'] False
# चिता 151 ['अग्नी', 'अंत्येष्टी'] False
# भट्टी 119 ['अग्नी', 'अड्डा'] False
# दहन 151 ['अग्नी', 'अंत्येष्टी'] False
# दाह 172 ['अग्नी', 'अग्नी'] True
# भाजणे 172 ['अग्नी', 'अग्नी'] True
# अणकुची 37 ['अग्र', 'अणकुची'] False
# शिखर 58 ['अग्र', 'अंत'] False
# अध्वर्यू 44 ['अग्रगण्य', 'अध्यक्ष'] False
# धुरीण 44 ['अग्रगण्य', 'अध्यक्ष'] False
# श्रेष्ठ 50 ['अग्रगण्य', 'अचाट'] False
# सर्वश्रेष्ठ 56 ['अग्रगण्य', 'अजोड'] False
# परम 80 ['अग्रगण्य', 'अतिशय'] False
# लोकोत्तर 56 ['अग्रगण्य', 'अजोड'] False
# निपुण 59 ['अग्रगण्य', 'अट्टल'] False
# अध्यक्ष 44 ['अग्रगण्य', 'अध्यक्ष'] False
# विलक्षण 35 ['अघटित', 'अचाट'] False
# अद्भुत 35 ['अघटित', 'अचाट'] False
# दुष्ट 76 ['अघोरी', 'अत्याचार', 'अधम'] False
# सैतानी 57 ['अघोरी', 'अधम'] False
# पाशवी 43 ['अघोरी', 'अत्याचार'] False
# अमानुष 43 ['अघोरी', 'अत्याचार'] False
# रानटी 43 ['अघोरी', 'अत्याचार'] False
# निंद्य 57 ['अघोरी', 'अधम'] False
# अतिरेकी 38 ['अघोरी', 'अतिरेकी', 'अतिशयोक्त'] False
# पक्का 62 ['अचल', 'अट्टल'] False
# निश्चेष्ट 43 ['अचल', 'अचेतन'] False
# अलौकिक 50 ['अचाट', 'अजोड'] False
# असामान्य 50 ['अचाट', 'अजोड'] False
# बेसुमार 74 ['अचाट', 'अतिशय'] False
# अतिशय 74 ['अचाट', 'अतिशय'] False
# निर्दोष 31 ['अचूक', 'अनघ'] False
# विश्वसनीय 45 ['अचूक', 'अट्टल'] False
# अमोघ 23 ['अचूक', 'अजिंक्य'] False
# जड 97 ['अचेतन', 'अजाण'] False
# शंका 46 ['अजमास', 'अढी'] False
# अकुशल 122 ['अजागळ', 'अजाण', 'अननुभवी'] False
# अजाण 98 ['अजाण', 'अननुभवी'] False
# अनभ्यस्त 98 ['अजाण', 'अननुभवी'] False
# अडाणी 98 ['अजाण', 'अडमुठा'] False
# अननुभवी 98 ['अजाण', 'अननुभवी'] False
# अपक्व 98 ['अजाण', 'अननुभवी'] False
# व्यवहारशून्य 170 ['अजाण', 'अजाण'] True
# अशिक्षित 98 ['अजाण', 'अननुभवी'] False
# बुद्धिमंद 106 ['अजाण', 'अधू'] False
# मूर्ख 98 ['अजाण', 'अडमुठा'] False
# बैलोबा 98 ['अजाण', 'अडमुठा'] False
# अट 68 ['अट', 'अटकाव'] False
# अटक 69 ['अटक', 'अटकाव'] False
# अडथळा 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# अडसर 77 ['अटकाव', 'अडगळ'] False
# अडचण 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# व्यत्यय 99 ['अटकाव', 'अडगळ', 'अडचण'] False
# विघ्न 83 ['अटकाव', 'अडचण'] False
# विक्षेप 91 ['अटकाव', 'अंतर'] False
# खंड 108 ['अटकाव', 'अंतर', 'अध्याय'] False
# संकट 83 ['अटकाव', 'अडचण'] False
# अंतराय 91 ['अटकाव', 'अंतर'] False
# प्रतिबंध 122 ['अटकाव', 'अटकाव'] True
# विरोध 91 ['अटकाव', 'अंतर'] False
# भाग 31 ['अटळ', 'अंतर्भाव', 'अध्याय'] False
# अडणे 44 ['अडकणे', 'अडकणे'] True
# तळ 72 ['अड्डा', 'अंत'] False
# स्थान 75 ['अड्डा', 'अधिकार', 'अधिष्ठान'] False
# न्यूनाधिक्य 60 ['अंतर', 'अंतर'] True
# मधला 27 ['अंतरिम', 'अंतर्गत'] False
# शिरकाव 19 ['अंतर्भाव', 'अतिक्रमण'] False
# अतिरेक 41 ['अतिरेक', 'अत्याचार'] False
# असीम 68 ['अतिशय', 'अनंत'] False
# अपार 68 ['अतिशय', 'अनंत'] False
# अपरिमित 68 ['अतिशय', 'अनंत'] False
# अमित 68 ['अतिशय', 'अनंत'] False
# अमाप 68 ['अतिशय', 'अनंत'] False
# अपरंपार 68 ['अतिशय', 'अनंत'] False
# अवाजवी 59 ['अतिशय', 'अतिशयोक्त'] False
# फार 63 ['अतिशय', 'अधिक'] False
# उदंड 104 ['अतिशय', 'अतिशय'] True
# अतृप्त 23 ['अतृप्त', 'अधाशी'] False
# हावरट 23 ['अतृप्त', 'अधाशी'] False
# अधाशी 23 ['अतृप्त', 'अधाशी'] False
# लोभी 23 ['अतृप्त', 'अधाशी'] False
# उमेदवार 30 ['अंतेवासी', 'अननुभवी'] False
# अधिष्ठान 42 ['अधिकार', 'अधिष्ठान'] False
# अधिकारी 33 ['अधिकारी', 'अध्यक्ष'] False
# स्वामी 33 ['अधिकारी', 'अध्यक्ष'] False
# धनी 33 ['अधिकारी', 'अध्यक्ष'] False
# मालक 33 ['अधिकारी', 'अध्यक्ष'] False
# अधीक्षक 37 ['अधिकारी', 'अधीक्षक', 'अध्यक्ष'] False
# नियामक 33 ['अधिकारी', 'अध्यक्ष'] False
# बैठक 20 ['अधिवेशन', 'अधिष्ठान'] False
# पीछेहाट 70 ['अधोगती', 'अधोगती'] True

# %%
newdict = dict()
for k in mydict.keys():
    mylist = mydict[k]
    mylist.sort(key=len)
    templist = list()
    templist.append(mylist[0])
    for i in mylist[1:]:
        if i[0] == k:
            pass
        else:
            i.remove(k)
        templist.append(i)
    newdict[k] = templist

# %%
finaldict = defaultdict(list)
for k in newdict.keys():
    mylist = newdict[k]
    for i in mylist:
        finaldict[i[0]].append(set(i[1:]))

# %%
fdict = dict()
for k in finaldict.keys():
    fdict[k] = set.intersection(*finaldict[k])

# %%
myobj = open("/tmp/newfile.txt", "w")

# %%
mysys = sys.stdout
sys.stdout = myobj

# %%
for k in fdict.keys():
    print(k + ",", ", ".join(fdict[k]))

# %%
lfile = open("/tmp/lfile.txt", "w")

# %%
sys.stdout = lfile

# %%
# !sed -i '/^$/d' /tmp/newfile.txt
# !sed -i '/^$/d' /tmp/sw2.txt

# %%
with open("/tmp/newfile.txt", "r") as n:
    finlist = dict()
    for nline in n:
        finlist[nline.split()[0]] = nline.split()[1:]

# %%
with open("/tmp/sw2.txt", "r") as f:
    for fline in f:
        if fline.split()[0] in finlist:
            print(fline.split()[0], " ".join(finlist[fline.split()[0]]))
        else:
            print(fline)

# %%
# !sed -i '/^$/d' /tmp/lfile.txt
